# %%
###-----------------
### Import libraries
###-----------------
from pathlib import Path  # Import Path for file system path operations and management
import numpy as np  # Import NumPy for numerical computations and array operations
import pandas as pd  # Import Pandas for data manipulation and analysis with DataFrames
import matplotlib.pyplot as plt  # Import Matplotlib for creating static, interactive visualizations
import seaborn as sns  # Import Seaborn for statistical data visualization built on Matplotlib

from sklearn.model_selection import train_test_split  # Import function to split dataset into training and testing subsets
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score  # Import function to calculate various metric

from collections.abc import Callable  # Type hinting callable objects/functions
from typing import Literal  # Literal type hints to restrict variable values

from sklearn.preprocessing import StandardScaler  # Import for standardizing features (zero mean, unit variance)
import tensorflow as tf
from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix # Custom utility

# %% [markdown]
# \begin{align*}
# & X \rightarrow X \cdot W_1 + b_1 \rightarrow \text{activation fnc }(g) \text{ (i.e. } a_1) \rightarrow a_1 \cdot W_2 + b_2 \rightarrow \text{(output } a_2) \rightarrow \text{Loss calculate} \\
# & \quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad|\\
# & \quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad dz_2 = (a_2 - y) \leftarrow \\
# & \quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad dw_2 = (a_1 \cdot dz_2) \\
# & \quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad db = dz_2 \\
# & \\
# & a_1 = g(z_1) \quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad\quad da_1 = W \cdot dz_2 \\
# & \frac{\partial}{\partial a_1} = da_1 \\
# & dz_1 = \frac{\partial L}{\partial a_1} \frac{\partial a_1}{\partial z_1} \\
# & \\
# & dw_1 = X \cdot dz_1 \\
# & db_1 = dz_1
# \end{align*}

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = Path('..') / '..' / 'input'
outDir = Path('..') / 'output'
modelDir = Path('..') / 'models'
subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 101 # number of epochs
BATCH_SIZE = 64
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_df = pd.read_csv('fifa_2019.csv')
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  object
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  object
#  19  Body Type                 18159 non-null  object
#  20  Real Face                 18159 non-null  object
#  21  Position                  18147 non-null  object
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  object
#  24  Loaned From               1264 non-null   object
#  25  Contract Valid Until      17918 non-null  object
#  26  Height                    18159 non-null  object
#  27  Weight                    18159 non-null  object
#  28  LS                        16122 non-null  object
#  29  ST                        16122 non-null  object
#  30  RS                        16122 non-null  object
#  31  LW                        16122 non-null  object
#  32  LF                        16122 non-null  object
#  33  CF                        16122 non-null  object
#  34  RF                        16122 non-null  object
#  35  RW                        16122 non-null  object
#  36  LAM                       16122 non-null  object
#  37  CAM                       16122 non-null  object
#  38  RAM                       16122 non-null  object
#  39  LM                        16122 non-null  object
#  40  LCM                       16122 non-null  object
#  41  CM                        16122 non-null  object
#  42  RCM                       16122 non-null  object
#  43  RM                        16122 non-null  object
#  44  LWB                       16122 non-null  object
#  45  LDM                       16122 non-null  object
#  46  CDM                       16122 non-null  object
#  47  RDM                       16122 non-null  object
#  48  RWB                       16122 non-null  object
#  49  LB                        16122 non-null  object
#  50  LCB                       16122 non-null  object
#  51  CB                        16122 non-null  object
#  52  RCB                       16122 non-null  object
#  53  RB                        16122 non-null  object
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
data_df = data_df[rel_cols]
data_df = data_df[data_df['Position'].notnull()]
data_df.info(), data_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18147 entries, 0 to 18206
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         18147 non-null  object
#  1   Finishing        18147 non-null  float64
#  2   HeadingAccuracy  18147 non-null  float64
#  3   ShortPassing     18147 non-null  float64
#  4   Volleys          18147 non-null  float64
#  5   Dribbling        18147 non-null  float64
#  6   Curve            18147 non-null  float64
#  7   FKAccuracy       18147 non-null  float64
#  8   LongPassing      18147 non-null  float64
#  9   BallControl      18147 non-null  float64
#  10  Acceleration     18147 non-null  float64
#  11  SprintSpeed      18147 non-null  float64
#  12  Agility          18147 non-null  float64
#  13  Reactions        18147 non-null  float64
#  14  Balance          18147 non-null  float64
#  15  ShotPower        18147 non-null  float64
#  16  Jumping          18147 non-null  float64
#  17  Stamina          18147 non-null  float64
#  18  Strength         18147 non-null  float64
#  19  LongShots        18147 non-null  float64
#  20  Aggression       18147 non-null  float64
#  21  Interceptions    18147 non-null  float64
#  22  Positioning      18147 non-null  float64
#  23  Vision           18147 non-null  float64
#  24  Penalties        18147 non-null  float64
#  25  Composure        18147 non-null  float64
#  26  Marking          18147 non-null  float64
#  27  StandingTackle   18147 non-null  float64
#  28  SlidingTackle    18147 non-null  float64
#  29  GKDiving         18147 non-null  float64
#  30  GKHandling       18147 non-null  float64
#  31  GKKicking        18147 non-null  float64
#  32  GKPositioning    18147 non-null  float64
#  33  GKReflexes       18147 non-null  float64
# dtypes: float64(33), object(1)
# memory usage: 4.8+ MB
# (None,
#  Position           0
#  Finishing          0
#  HeadingAccuracy    0
#  ShortPassing       0
#  Volleys            0
#  Dribbling          0
#  Curve              0
#  FKAccuracy         0
#  LongPassing        0
#  BallControl        0
#  Acceleration       0
#  SprintSpeed        0
#  Agility            0
#  Reactions          0
#  Balance            0
#  ShotPower          0
#  Jumping            0
#  Stamina            0
#  Strength           0
#  LongShots          0
#  Aggression         0
#  Interceptions      0
#  Positioning        0
#  Vision             0
#  Penalties          0
#  Composure          0
#  Marking            0
#  StandingTackle     0
#  SlidingTackle      0
#  GKDiving           0
#  GKHandling         0
#  GKKicking          0
#  GKPositioning      0
#  GKReflexes         0
#  dtype: int64)

# %%
data_df.loc[data_df['Position'] == "GK", 'Position'] = 0
data_df.loc[data_df['Position'].isin(defender), 'Position'] = 1
data_df.loc[data_df['Position'].isin(midfielder), 'Position'] = 2
data_df.loc[data_df['Position'].isin(forward), 'Position'] = 3

data_df['Position'] = pd.to_numeric(data_df['Position'], downcast='integer') # to int8 else it was int64

data_df.dtypes
# Out:
# Position              int8
# Finishing          float64
# HeadingAccuracy    float64
# ShortPassing       float64
# Volleys            float64
# Dribbling          float64
# Curve              float64
# FKAccuracy         float64
# LongPassing        float64
# BallControl        float64
# Acceleration       float64
# SprintSpeed        float64
# Agility            float64
# Reactions          float64
# Balance            float64
# ShotPower          float64
# Jumping            float64
# Stamina            float64
# Strength           float64
# LongShots          float64
# Aggression         float64
# Interceptions      float64
# Positioning        float64
# Vision             float64
# Penalties          float64
# Composure          float64
# Marking            float64
# StandingTackle     float64
# SlidingTackle      float64
# GKDiving           float64
# GKHandling         float64
# GKKicking          float64
# GKPositioning      float64
# GKReflexes         float64
# dtype: object

# %%
class_labels = {
    0: 'Goal Keeper', 
    1: 'Defender',
    2: 'Mid-fielder',
    3: 'Forward'
}

# %%
labels = data_df['Position']
features_df = data_df.drop('Position', axis=1)
features_df.shape, labels.shape
# Out:
# ((18147, 33), (18147,))

# %%
X_train, X_test, y_train, y_test = train_test_split(features_df, labels, test_size=TEST_SIZE, random_state=RANDOM_STATE, stratify=labels)

std = StandardScaler()
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

X_train.shape, X_test.shape, y_train.shape , y_test.shape
# Out:
# ((14517, 33), (3630, 33), (14517,), (3630,))

# %%
type(X_train), type(X_test), type(y_train), type(y_test)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %% [markdown]
# Converting to Datasets

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) # a we are passing rows of data thats why slices. it is creating dataset for us
test_ds = tf.data.Dataset.from_tensor_slices((X_test,y_test))
# Out:
# (<tf.Tensor: shape=(33,), dtype=float64, numpy=
#  array([ 0.84396466,  0.27358763, -0.52239617,  0.23109725,  0.29705091,
#         -0.28022877, -0.90549975, -0.76923736,  0.03641655,  0.69690341,
#          0.56150403,  0.64223997, -0.31191556,  0.42687437,  0.09102389,
#         -0.00583853, -0.0156703 , -0.26906524,  0.14948988, -0.39569289,
#         -1.58556533,  0.56596068, -0.45127189,  0.92378593, -0.5824395 ,
#         -1.31972485, -1.46321229, -1.58353669, -0.31775841, -0.55501322,
#         -0.37748688, -0.25744747, -0.31840455])>,
#  <tf.Tensor: shape=(), dtype=int8, numpy=3>)

# %%
iter(train_ds).next()
# Out:
# (<tf.Tensor: shape=(33,), dtype=float64, numpy=
#  array([ 0.84396466,  0.27358763, -0.52239617,  0.23109725,  0.29705091,
#         -0.28022877, -0.90549975, -0.76923736,  0.03641655,  0.69690341,
#          0.56150403,  0.64223997, -0.31191556,  0.42687437,  0.09102389,
#         -0.00583853, -0.0156703 , -0.26906524,  0.14948988, -0.39569289,
#         -1.58556533,  0.56596068, -0.45127189,  0.92378593, -0.5824395 ,
#         -1.31972485, -1.46321229, -1.58353669, -0.31775841, -0.55501322,
#         -0.37748688, -0.25744747, -0.31840455])>,
#  <tf.Tensor: shape=(), dtype=int8, numpy=3>)

# %%
train_ds = train_ds.shuffle(buffer_size=X_train.shape[0]).batch(BATCH_SIZE) 
test_ds = test_ds.shuffle(buffer_size=X_test.shape[0]).batch(BATCH_SIZE)

# %%
train_ds = train_ds.cache().prefetch(buffer_size=  tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=  tf.data.AUTOTUNE)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 33), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.int8, name=None))>

# %%
for fetures,labels in  train_ds.take(5):
    print(fetures.shape,labels.shape)
# Out:
# (64, 33) (64,)
# (64, 33) (64,)
# (64, 33) (64,)
# (64, 33) (64,)
# (64, 33) (64,)

# %% [markdown]
# <h1>Define Model</h1>

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape = (33,)),
    tf.keras.layers.Dense(27,activation='relu'),
    tf.keras.layers.Dense(21,activation='relu'),
    tf.keras.layers.Dense(15,activation='relu'),
    tf.keras.layers.Dense(9,activation='relu'),
    tf.keras.layers.Dense(4)
])

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model.compile(optimizer = optimizer,
             loss = loss_fn,
             metrics = ['accuracy'])

# %%
history = model.fit(train_ds,
                    validation_data=test_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7610 - loss: 0.5726 - val_accuracy: 0.8523 - val_loss: 0.3475
# Epoch 2/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8679 - loss: 0.3240 - val_accuracy: 0.8628 - val_loss: 0.3191
# Epoch 3/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8748 - loss: 0.3069 - val_accuracy: 0.8639 - val_loss: 0.3147
# Epoch 4/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8780 - loss: 0.2996 - val_accuracy: 0.8647 - val_loss: 0.3114
# Epoch 5/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8803 - loss: 0.2948 - val_accuracy: 0.8672 - val_loss: 0.3087
# Epoch 6/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8808 - loss: 0.2912 - val_accuracy: 0.8669 - val_loss: 0.3076
# Epoch 7/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8815 - loss: 0.2883 - val_accuracy: 0.8686 - val_loss: 0.3057
# Epoch 8/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8817 - loss: 0.2859 - val_accuracy: 0.8658 - val_loss: 0.3051
# Epoch 9/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8825 - loss: 0.2836 - val_accuracy: 0.8672 - val_loss: 0.3032
# Epoch 10/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8830 - loss: 0.2816 - val_accuracy: 0.8678 - val_loss: 0.3028
# Epoch 11/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8834 - loss: 0.2798 - val_accuracy: 0.8680 - val_loss: 0.3024
# Epoch 12/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8846 - loss: 0.2784 - val_accuracy: 0.8675 - val_loss: 0.3013
# Epoch 13/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8850 - loss: 0.2766 - val_accuracy: 0.8658 - val_loss: 0.3019
# Epoch 14/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8857 - loss: 0.2751 - val_accuracy: 0.8689 - val_loss: 0.3018
# Epoch 15/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8864 - loss: 0.2737 - val_accuracy: 0.8694 - val_loss: 0.3013
# Epoch 16/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8869 - loss: 0.2723 - val_accuracy: 0.8697 - val_loss: 0.3019
# Epoch 17/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8870 - loss: 0.2712 - val_accuracy: 0.8686 - val_loss: 0.3019
# Epoch 18/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8875 - loss: 0.2699 - val_accuracy: 0.8683 - val_loss: 0.3025
# Epoch 19/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8883 - loss: 0.2688 - val_accuracy: 0.8678 - val_loss: 0.3025
# Epoch 20/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8880 - loss: 0.2677 - val_accuracy: 0.8675 - val_loss: 0.3026
# Epoch 21/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8885 - loss: 0.2669 - val_accuracy: 0.8678 - val_loss: 0.3031
# Epoch 22/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8890 - loss: 0.2660 - val_accuracy: 0.8675 - val_loss: 0.3026
# Epoch 23/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8892 - loss: 0.2651 - val_accuracy: 0.8667 - val_loss: 0.3032
# Epoch 24/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8898 - loss: 0.2641 - val_accuracy: 0.8678 - val_loss: 0.3032
# Epoch 25/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8901 - loss: 0.2633 - val_accuracy: 0.8686 - val_loss: 0.3042
# Epoch 26/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8904 - loss: 0.2623 - val_accuracy: 0.8686 - val_loss: 0.3074
# Epoch 27/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8910 - loss: 0.2616 - val_accuracy: 0.8686 - val_loss: 0.3076
# Epoch 28/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8909 - loss: 0.2609 - val_accuracy: 0.8669 - val_loss: 0.3088
# Epoch 29/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8923 - loss: 0.2600 - val_accuracy: 0.8689 - val_loss: 0.3084
# Epoch 30/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8920 - loss: 0.2593 - val_accuracy: 0.8683 - val_loss: 0.3094
# Epoch 31/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8930 - loss: 0.2584 - val_accuracy: 0.8675 - val_loss: 0.3105
# Epoch 32/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8931 - loss: 0.2577 - val_accuracy: 0.8683 - val_loss: 0.3110
# Epoch 33/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8929 - loss: 0.2570 - val_accuracy: 0.8683 - val_loss: 0.3120
# Epoch 34/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8931 - loss: 0.2563 - val_accuracy: 0.8675 - val_loss: 0.3116
# Epoch 35/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8930 - loss: 0.2555 - val_accuracy: 0.8667 - val_loss: 0.3129
# Epoch 36/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8933 - loss: 0.2548 - val_accuracy: 0.8661 - val_loss: 0.3129
# Epoch 37/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8935 - loss: 0.2542 - val_accuracy: 0.8669 - val_loss: 0.3140
# Epoch 38/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8939 - loss: 0.2536 - val_accuracy: 0.8675 - val_loss: 0.3139
# Epoch 39/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8944 - loss: 0.2529 - val_accuracy: 0.8667 - val_loss: 0.3151
# Epoch 40/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8950 - loss: 0.2522 - val_accuracy: 0.8658 - val_loss: 0.3155
# Epoch 41/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8951 - loss: 0.2515 - val_accuracy: 0.8664 - val_loss: 0.3148
# Epoch 42/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8958 - loss: 0.2509 - val_accuracy: 0.8653 - val_loss: 0.3152
# Epoch 43/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8965 - loss: 0.2503 - val_accuracy: 0.8645 - val_loss: 0.3153
# Epoch 44/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8964 - loss: 0.2496 - val_accuracy: 0.8639 - val_loss: 0.3161
# Epoch 45/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8971 - loss: 0.2491 - val_accuracy: 0.8639 - val_loss: 0.3165
# Epoch 46/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8974 - loss: 0.2485 - val_accuracy: 0.8636 - val_loss: 0.3159
# Epoch 47/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8976 - loss: 0.2479 - val_accuracy: 0.8647 - val_loss: 0.3177
# Epoch 48/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8976 - loss: 0.2474 - val_accuracy: 0.8628 - val_loss: 0.3185
# Epoch 49/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8982 - loss: 0.2465 - val_accuracy: 0.8639 - val_loss: 0.3184
# Epoch 50/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8983 - loss: 0.2459 - val_accuracy: 0.8642 - val_loss: 0.3188
# Epoch 51/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8983 - loss: 0.2452 - val_accuracy: 0.8645 - val_loss: 0.3197
# Epoch 52/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8984 - loss: 0.2445 - val_accuracy: 0.8645 - val_loss: 0.3192
# Epoch 53/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8987 - loss: 0.2440 - val_accuracy: 0.8636 - val_loss: 0.3207
# Epoch 54/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8981 - loss: 0.2434 - val_accuracy: 0.8634 - val_loss: 0.3220
# Epoch 55/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8992 - loss: 0.2429 - val_accuracy: 0.8628 - val_loss: 0.3235
# Epoch 56/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8987 - loss: 0.2422 - val_accuracy: 0.8645 - val_loss: 0.3233
# Epoch 57/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8998 - loss: 0.2415 - val_accuracy: 0.8628 - val_loss: 0.3265
# Epoch 58/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9003 - loss: 0.2410 - val_accuracy: 0.8631 - val_loss: 0.3252
# Epoch 59/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9002 - loss: 0.2403 - val_accuracy: 0.8628 - val_loss: 0.3247
# Epoch 60/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9009 - loss: 0.2399 - val_accuracy: 0.8636 - val_loss: 0.3264
# Epoch 61/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9010 - loss: 0.2392 - val_accuracy: 0.8614 - val_loss: 0.3262
# Epoch 62/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9007 - loss: 0.2387 - val_accuracy: 0.8628 - val_loss: 0.3281
# Epoch 63/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9013 - loss: 0.2378 - val_accuracy: 0.8625 - val_loss: 0.3297
# Epoch 64/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9007 - loss: 0.2374 - val_accuracy: 0.8625 - val_loss: 0.3307
# Epoch 65/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9008 - loss: 0.2368 - val_accuracy: 0.8628 - val_loss: 0.3311
# Epoch 66/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9014 - loss: 0.2361 - val_accuracy: 0.8612 - val_loss: 0.3326
# Epoch 67/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9014 - loss: 0.2356 - val_accuracy: 0.8609 - val_loss: 0.3323
# Epoch 68/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9017 - loss: 0.2352 - val_accuracy: 0.8601 - val_loss: 0.3329
# Epoch 69/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9021 - loss: 0.2345 - val_accuracy: 0.8603 - val_loss: 0.3344
# Epoch 70/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9023 - loss: 0.2340 - val_accuracy: 0.8612 - val_loss: 0.3331
# Epoch 71/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9018 - loss: 0.2332 - val_accuracy: 0.8598 - val_loss: 0.3349
# Epoch 72/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9027 - loss: 0.2328 - val_accuracy: 0.8598 - val_loss: 0.3361
# Epoch 73/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9029 - loss: 0.2322 - val_accuracy: 0.8614 - val_loss: 0.3356
# Epoch 74/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9045 - loss: 0.2311 - val_accuracy: 0.8620 - val_loss: 0.3348
# Epoch 75/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9042 - loss: 0.2306 - val_accuracy: 0.8623 - val_loss: 0.3366
# Epoch 76/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9036 - loss: 0.2303 - val_accuracy: 0.8631 - val_loss: 0.3360
# Epoch 77/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9046 - loss: 0.2295 - val_accuracy: 0.8634 - val_loss: 0.3359
# Epoch 78/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9052 - loss: 0.2291 - val_accuracy: 0.8628 - val_loss: 0.3369
# Epoch 79/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9050 - loss: 0.2283 - val_accuracy: 0.8623 - val_loss: 0.3394
# Epoch 80/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9056 - loss: 0.2277 - val_accuracy: 0.8612 - val_loss: 0.3418
# Epoch 81/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9061 - loss: 0.2277 - val_accuracy: 0.8625 - val_loss: 0.3430
# Epoch 82/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9063 - loss: 0.2267 - val_accuracy: 0.8606 - val_loss: 0.3449
# Epoch 83/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9066 - loss: 0.2260 - val_accuracy: 0.8628 - val_loss: 0.3448
# Epoch 84/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9062 - loss: 0.2255 - val_accuracy: 0.8623 - val_loss: 0.3467
# Epoch 85/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9068 - loss: 0.2250 - val_accuracy: 0.8623 - val_loss: 0.3470
# Epoch 86/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9069 - loss: 0.2241 - val_accuracy: 0.8623 - val_loss: 0.3485
# Epoch 87/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9065 - loss: 0.2238 - val_accuracy: 0.8620 - val_loss: 0.3495
# Epoch 88/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9077 - loss: 0.2231 - val_accuracy: 0.8612 - val_loss: 0.3534
# Epoch 89/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9075 - loss: 0.2228 - val_accuracy: 0.8625 - val_loss: 0.3552
# Epoch 90/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9080 - loss: 0.2221 - val_accuracy: 0.8606 - val_loss: 0.3558
# Epoch 91/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9085 - loss: 0.2217 - val_accuracy: 0.8603 - val_loss: 0.3570
# Epoch 92/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9083 - loss: 0.2214 - val_accuracy: 0.8612 - val_loss: 0.3563
# Epoch 93/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9091 - loss: 0.2205 - val_accuracy: 0.8598 - val_loss: 0.3567
# Epoch 94/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9090 - loss: 0.2193 - val_accuracy: 0.8609 - val_loss: 0.3595
# Epoch 95/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9099 - loss: 0.2191 - val_accuracy: 0.8609 - val_loss: 0.3585
# Epoch 96/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9104 - loss: 0.2182 - val_accuracy: 0.8601 - val_loss: 0.3576
# Epoch 97/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9097 - loss: 0.2184 - val_accuracy: 0.8595 - val_loss: 0.3602
# Epoch 98/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9107 - loss: 0.2172 - val_accuracy: 0.8598 - val_loss: 0.3601
# Epoch 99/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9105 - loss: 0.2170 - val_accuracy: 0.8601 - val_loss: 0.3617
# Epoch 100/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9105 - loss: 0.2163 - val_accuracy: 0.8581 - val_loss: 0.3639
# Epoch 101/101
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9104 - loss: 0.2166 - val_accuracy: 0.8579 - val_loss: 0.3640

# %%
model.evaluate(train_ds,verbose=2)
# Out:
# 227/227 - 0s - 1ms/step - accuracy: 0.8967 - loss: 0.2392
# [0.23924694955348969, 0.8967417478561401]

# %% [markdown]
# <h1>Prediction</h1>

# %%
y_true,y_pred = [],[]
for feat,lbls in train_ds:
    pred = model(feat).numpy()
    y_true.extend(lbls)
    y_pred.extend(pred.argmax(axis = 1))
print(f'Accuracy : {accuracy_score(y_true,y_pred)}')
print(f'Accuracy : {classification_report(y_true,y_pred)}')
# Out:
# Accuracy : 0.8967417510504925
# Accuracy :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1620
#            1       0.89      0.98      0.93      4693
#            2       0.87      0.85      0.86      5470
#            3       0.89      0.79      0.84      2734
#
#     accuracy                           0.90     14517
#    macro avg       0.91      0.90      0.91     14517
# weighted avg       0.90      0.90      0.90     14517

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)
