# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 9
#
# ## Torch DataSSets
# - Fifa Dataset
# <img src='../../prasami_images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com"/>

# %% [markdown]
# ## Import Statements

# %%
###-----------------
### Import libraries
###-----------------
from pathlib import Path         # Import Path for file system path operations and management
import numpy as np               # Import NumPy for numerical computations and array operations
import pandas as pd              # Import Pandas for data manipulation and analysis with DataFrames
import matplotlib.pyplot as plt  # Import Matplotlib for creating static, interactive visualizations
import seaborn as sns            # Import Seaborn for statistical data visualization built on Matplotlib

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import (accuracy_score, 
                             classification_report, 
                             confusion_matrix, 
                             ConfusionMatrixDisplay, 
                             f1_score)                 # to calculate various metric

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset

from utils.helper import fn_plot_torch_hist, fn_plot_confusion_matrix

# %%
# ###------------------
# ### Global Parameters
# ###------------------

# Directories
inpDir = Path('..') / '..' / 'input'
outDir = Path('..') / 'output'
fileName = 'fifa_2019.csv'

RANDOM_STATE = 24 
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
torch.manual_seed(RANDOM_STATE)


EPOCHS = 100
ALPHA = 0.001
BATCH_SIZE = 32
TEST_SIZE  = 0.2 # Size of test data
TRAIN_SIZE = 454 * BATCH_SIZE 

# Parameters for plotting
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params)

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
18147*0.8/32
# Out:
# 453.675

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
data_df = pd.read_csv(inpDir/fileName)
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
data_df = data_df[rel_cols]
data_df =data_df[data_df['Position'].notnull()]
data_df.head()
# Out:
#   Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0       RF       95.0             70.0          90.0     86.0       97.0
# 1       ST       94.0             89.0          81.0     87.0       88.0
# 2       LW       87.0             62.0          84.0     84.0       96.0
# 3       GK       13.0             21.0          50.0     13.0       18.0
# 4      RCM       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18147 entries, 0 to 18206
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         18147 non-null  object
#  1   Finishing        18147 non-null  float64
#  2   HeadingAccuracy  18147 non-null  float64
#  3   ShortPassing     18147 non-null  float64
#  4   Volleys          18147 non-null  float64
#  5   Dribbling        18147 non-null  float64
#  6   Curve            18147 non-null  float64
#  7   FKAccuracy       18147 non-null  float64
#  8   LongPassing      18147 non-null  float64
#  9   BallControl      18147 non-null  float64
#  10  Acceleration     18147 non-null  float64
#  11  SprintSpeed      18147 non-null  float64
#  12  Agility          18147 non-null  float64
#  13  Reactions        18147 non-null  float64
#  14  Balance          18147 non-null  float64
#  15  ShotPower        18147 non-null  float64
#  16  Jumping          18147 non-null  float64
#  17  Stamina          18147 non-null  float64
#  18  Strength         18147 non-null  float64
#  19  LongShots        18147 non-null  float64
#  20  Aggression       18147 non-null  float64
#  21  Interceptions    18147 non-null  float64
#  22  Positioning      18147 non-null  float64
#  23  Vision           18147 non-null  float64
#  24  Penalties        18147 non-null  float64
#  25  Composure        18147 non-null  float64
#  26  Marking          18147 non-null  float64
#  27  StandingTackle   18147 non-null  float64
#  28  SlidingTackle    18147 non-null  float64
#  29  GKDiving         18147 non-null  float64
#  30  GKHandling       18147 non-null  float64
#  31  GKKicking        18147 non-null  float64
#  32  GKPositioning    18147 non-null  float64
#  33  GKReflexes       18147 non-null  float64
# dtypes: float64(33), object(1)
# memory usage: 4.8+ MB

# %%
data_df.describe().T
# Out:
#                    count       mean        std   min   25%   50%   75%   max
# Finishing        18147.0  45.550229  19.527445   2.0  30.0  49.0  62.0  95.0
# HeadingAccuracy  18147.0  52.300766  17.381753   4.0  44.0  56.0  64.0  94.0
# ShortPassing     18147.0  58.695432  14.696075   7.0  54.0  62.0  68.0  93.0
# Volleys          18147.0  42.912217  17.695900   4.0  30.0  44.0  57.0  90.0
# Dribbling        18147.0  55.375158  18.912224   4.0  49.0  61.0  68.0  97.0
# Curve            18147.0  47.176283  18.396009   6.0  34.0  48.0  62.0  94.0
# FKAccuracy       18147.0  42.866038  17.480034   3.0  31.0  41.0  57.0  94.0
# LongPassing      18147.0  52.721386  15.325211   9.0  43.0  56.0  64.0  93.0
# BallControl      18147.0  58.374828  16.685643   5.0  54.0  63.0  69.0  96.0
# Acceleration     18147.0  64.612829  14.930320  12.0  57.0  67.0  75.0  97.0
# SprintSpeed      18147.0  64.726236  14.651776  12.0  57.0  67.0  75.0  96.0
# Agility          18147.0  63.501295  14.768956  14.0  55.0  66.0  74.0  96.0
# Reactions        18147.0  61.839147   9.011056  21.0  56.0  62.0  68.0  96.0
#  19. 57. 56. 52. 53. 54. 47. 43. 32. 50. 51. 48. 49. 46. 45. 44.]
# Col: GKKicking - [15. 87.  5.  6.  7. 31.  9. 78. 12. 13. 10.  4. 11. 14. 88. 72. 91.  2.
#  16. 68. 69. 74. 75.  8.  3. 85. 71. 77. 82. 20. 76. 83. 79. 70. 52. 80.
#  73. 58.  1. 81. 64. 66. 65. 63. 62. 60. 67. 61. 38. 17. 42. 54. 18. 84.
#  59. 45. 46. 28. 57. 53. 56. 55. 19. 49. 41. 22. 40. 51. 33. 48. 23. 21.
#  47. 35. 50. 44. 30. 36. 43.]
# Col: GKPositioning - [14. 15. 88. 10.  8. 33.  7.  5.  6. 13. 85. 86.  9. 87. 11.  4. 12. 83.
#  89. 90. 82.  2. 16. 84. 81. 79. 80. 19.  3. 78. 77.  1. 75. 76. 74. 72.
#  32. 17. 73. 65. 70. 18. 71. 69. 20. 68. 67. 62. 24. 66. 64. 63. 30. 55.
#  59. 61. 60. 23. 57. 58. 50. 54. 51. 49. 56. 53. 52. 27. 38. 47. 48. 46.
#  44. 45. 41. 42. 43. 39. 40.]
# Col: GKReflexes - [ 8. 11. 94. 13.  9. 37. 89. 10. 15. 12. 14. 90. 88. 87.  3.  6. 92. 83.
#   5.  4.  7. 82. 84. 20. 86. 16. 85.  2. 18. 78. 81. 80. 79.  1. 76. 77.
#  75. 72. 34. 17. 74. 67. 73. 19. 66. 70. 71. 23. 69. 68. 33. 64. 21. 65.
#  61. 59. 63. 62. 60. 58. 56. 57. 53. 55. 25. 30. 54. 52. 51. 50. 49. 48.
#  46. 44. 45. 47.]

# %%
data_df.isna().sum()
# Out:
# Position           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
data_df.loc[data_df['Position'] == 'GK', 'Position'] = 0
data_df.loc[data_df['Position'].isin(defender), 'Position'] = 1
data_df.loc[data_df['Position'].isin(midfielder), 'Position'] = 2
data_df.loc[data_df['Position'].isin(forward), 'Position'] = 3

data_df['Position'] = pd.to_numeric(data_df['Position'], downcast='integer')

# %%
class_labels = {0: 'Goal Keeper', 
                1: 'Defender', 
                2: 'Mid-fielder', 
                3: 'Forward'}

# %%
train_df, test_df = train_test_split(data_df,
                                     stratify=data_df['Position'],
                                     train_size=TRAIN_SIZE,
                                     #test_size=TEST_SIZE,
                                     random_state=RANDOM_STATE)
train_df.shape, test_df.shape
# Out:
# ((14528, 34), (3619, 34))

# %% [markdown]
# ### Custom Dataset

# %%
class GlobalScaler:
    _instance = None

    def __init__(self):
        if GlobalScaler._instance is not None:
            raise Exception ('GlobalScaler is Singleton Class')
        self.scaler = StandardScaler()

    @classmethod
    def get_instance(cls):
        if cls._instance is None:
            cls._instance = GlobalScaler()
        return cls._instance

# %%
class FifaDS(Dataset):
    globalScaler =GlobalScaler.get_instance() # Protected variable

    def __init__(self, 
                 dataframe, 
                 device = device, 
                 is_train = True, 
                 label_col = None):
        self.df = dataframe
        self.device = device
        self.is_train= is_train
        self.scaler = self.globalScaler.scaler
        self.label_col = label_col

        self.labels = self.df[label_col].to_numpy()
        if self.is_train:
            X = self.df.drop(label_col, axis = 1)
            self.features = self.scaler.fit_transform(X)
        else:
            X = self.df.drop(label_col, axis = 1)
            self.features = self.scaler.transform(X)
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, index):
        feature = self.features[index]
        label = self.labels[index]
        return feature, label

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
type(X_train), type(X_test), type(y_train), type(y_test)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %% [markdown]
# ## Converting to Datasets

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763118199.439530   34468 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4095 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
train_ds = train_ds.shuffle(buffer_size=X_train.shape[0]).batch(BATCH_SIZE)
test_ds = test_ds.shuffle(buffer_size=X_test.shape[0]).batch(BATCH_SIZE)

# %%
train_ds = train_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
next(iter(train_ds))
# Out:
# 2025-11-14 16:33:20.342805: W tensorflow/core/kernels/data/cache_dataset_ops.cc:917] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# (<tf.Tensor: shape=(32, 33), dtype=float64, numpy=
#  array([[ 1.45736448,  1.19120541,  0.97380057, ..., -0.25648389,
#          -0.37503159, -0.26239981],
#         [-0.33529162,  0.84598612,  0.42924284, ..., -0.31708813,
#          -0.08146885, -0.09529454],
#         [-0.23285413,  0.21308409,  0.42924284, ..., -0.25648389,
#          -0.25760649, -0.26239981],
#         ...,
#         [ 0.27933333,  0.32815719,  0.2250337 , ..., -0.49890085,
#          -0.25760649, -0.03959278],
#         [-0.79626033, -0.64996413, -0.25145431, ..., -0.25648389,
#          -0.31631904, -0.59661035],
#         [-0.07919789,  0.09801099,  0.56538227, ..., -0.19587965,
#          -0.37503159, -0.42950508]], shape=(32, 33))>,
#  <tf.Tensor: shape=(32,), dtype=int8, numpy=
#  array([3, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 3, 3, 2, 3, 2,
#         1, 2, 0, 2, 1, 2, 3, 2, 2, 2], dtype=int8)>)

# %%
for features, labels in train_ds.take(5):
    print (features.shape, labels.shape)
# Out:
# (32, 33) (32,)
# (32, 33) (32,)
# (32, 33) (32,)
# (32, 33) (32,)
# (32, 33) (32,)
# 2025-11-14 16:33:20.441173: W tensorflow/core/kernels/data/cache_dataset_ops.cc:917] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-11-14 16:33:20.443341: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ### Define model

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(33,)),
    tf.keras.layers.Dense(66),
    tf.keras.layers.LeakyReLU(),
    tf.keras.layers.Dense(36),
    tf.keras.layers.LeakyReLU(),
    tf.keras.layers.Dense(4)
])

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)
model.compile(optimizer= optimizer,
              loss=loss_fn, metrics= ['accuracy'])

# %%
history = model.fit(train_ds, 
                    validation_data=test_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/100
# 2025-11-14 16:33:21.676144: I external/local_xla/xla/service/service.cc:163] XLA service 0x772494005690 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-14 16:33:21.676177: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-11-14 16:33:21.693000: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-14 16:33:21.781871: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-11-14 16:33:21.799732: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-14 16:33:21.799762: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-14 16:33:22.832895: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_365', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-11-14 16:33:22.864586: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_365', 44 bytes spill stores, 44 bytes spill loads
#
# 2025-11-14 16:33:23.311944: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_363', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-14 16:33:23.419010: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_363', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-14 16:33:23.455227: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_365', 368 bytes spill stores, 368 bytes spill loads
#
# 2025-11-14 16:33:23.530306: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_363', 152 bytes spill stores, 152 bytes spill loads
# 129/566 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7145 - loss: 0.7013
# I0000 00:00:1763118204.556159   34540 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8486 - loss: 0.3698 - val_accuracy: 0.9429 - val_loss: 0.1842
# Epoch 2/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8731 - loss: 0.3065 - val_accuracy: 0.9714 - val_loss: 0.1732
# Epoch 3/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8765 - loss: 0.2985 - val_accuracy: 0.9714 - val_loss: 0.1688
# Epoch 4/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8781 - loss: 0.2936 - val_accuracy: 0.9714 - val_loss: 0.1640
# Epoch 5/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8802 - loss: 0.2898 - val_accuracy: 0.9714 - val_loss: 0.1637
# Epoch 6/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8809 - loss: 0.2868 - val_accuracy: 0.9714 - val_loss: 0.1643
# Epoch 7/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8822 - loss: 0.2843 - val_accuracy: 0.9714 - val_loss: 0.1647
# Epoch 8/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8829 - loss: 0.2820 - val_accuracy: 0.9714 - val_loss: 0.1642
# Epoch 9/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8841 - loss: 0.2800 - val_accuracy: 0.9714 - val_loss: 0.1645
# Epoch 10/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8846 - loss: 0.2784 - val_accuracy: 0.9714 - val_loss: 0.1629
# Epoch 11/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8856 - loss: 0.2769 - val_accuracy: 0.9714 - val_loss: 0.1638
# Epoch 12/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8863 - loss: 0.2755 - val_accuracy: 0.9714 - val_loss: 0.1649
# Epoch 13/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8868 - loss: 0.2742 - val_accuracy: 0.9714 - val_loss: 0.1645
# Epoch 14/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8870 - loss: 0.2731 - val_accuracy: 0.9714 - val_loss: 0.1640
# Epoch 15/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8871 - loss: 0.2720 - val_accuracy: 0.9714 - val_loss: 0.1633
# Epoch 16/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8874 - loss: 0.2709 - val_accuracy: 0.9714 - val_loss: 0.1651
# Epoch 17/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8884 - loss: 0.2697 - val_accuracy: 0.9714 - val_loss: 0.1628
# Epoch 18/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8885 - loss: 0.2686 - val_accuracy: 0.9714 - val_loss: 0.1633
# Epoch 19/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8885 - loss: 0.2675 - val_accuracy: 0.9714 - val_loss: 0.1652
# Epoch 20/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8892 - loss: 0.2664 - val_accuracy: 0.9714 - val_loss: 0.1643
# Epoch 21/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.
100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9108 - loss: 0.2166 - val_accuracy: 0.9143 - val_loss: 0.1769
# Epoch 86/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9118 - loss: 0.2160 - val_accuracy: 0.9143 - val_loss: 0.1755
# Epoch 87/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9116 - loss: 0.2154 - val_accuracy: 0.9143 - val_loss: 0.1773
# Epoch 88/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9120 - loss: 0.2147 - val_accuracy: 0.9143 - val_loss: 0.1762
# Epoch 89/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9126 - loss: 0.2140 - val_accuracy: 0.9143 - val_loss: 0.1735
# Epoch 90/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9123 - loss: 0.2135 - val_accuracy: 0.9143 - val_loss: 0.1727
# Epoch 91/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9128 - loss: 0.2127 - val_accuracy: 0.9143 - val_loss: 0.1721
# Epoch 92/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9129 - loss: 0.2122 - val_accuracy: 0.9143 - val_loss: 0.1685
# Epoch 93/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9135 - loss: 0.2115 - val_accuracy: 0.9143 - val_loss: 0.1697
# Epoch 94/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9135 - loss: 0.2109 - val_accuracy: 0.9143 - val_loss: 0.1687
# Epoch 95/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9143 - loss: 0.2103 - val_accuracy: 0.9143 - val_loss: 0.1694
# Epoch 96/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9143 - loss: 0.2098 - val_accuracy: 0.9143 - val_loss: 0.1700
# Epoch 97/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9148 - loss: 0.2091 - val_accuracy: 0.9143 - val_loss: 0.1687
# Epoch 98/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9150 - loss: 0.2088 - val_accuracy: 0.9143 - val_loss: 0.1685
# Epoch 99/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9153 - loss: 0.2081 - val_accuracy: 0.9143 - val_loss: 0.1666
# Epoch 100/100
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9157 - loss: 0.2074 - val_accuracy: 0.9143 - val_loss: 0.1690

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
# model.evaluate(train_ds, verbose=2) # [0.2410917729139328, 0.9031480550765991]
# model.evaluate(test_ds, verbose=2) # [0.3128422796726227, 0.8727272748947144]

# %% [markdown]
# ### Predictions

# %%
y_true, y_pred = [], []
for feat, lbls in train_ds:
    pred = model(feat).numpy()
    y_true.extend(lbls)
    y_pred.extend(pred.argmax(axis=1))

print (f'Accuracy: {accuracy_score(y_true, y_pred):.4f}')
print (classification_report(y_true, y_pred))
# Out:
# 2025-11-14 16:34:33.677502: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Accuracy: 0.9148
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2021
#            1       0.93      0.96      0.95      5855
#            2       0.91      0.86      0.89      6825
#            3       0.85      0.89      0.87      3411
#
#     accuracy                           0.91     18112
#    macro avg       0.92      0.93      0.92     18112
# weighted avg       0.92      0.91      0.91     18112

# %%
fn_plot_confusion_matrix(y_true, y_pred, class_labels)

# %%
y_true, y_pred = [], []
for feat, lbls in tesfn_plot_confusion_matrix(y_true, y_pred, class_labels)t_ds:
    pred = model(feat).numpy()
    y_true.extend(lbls)
    y_pred.extend(pred.argmax(axis=1))

print (f'Accuracy: {accuracy_score(y_true, y_pred):.4f}')
print (classification_report(y_true, y_pred))
# Out:
# Accuracy: 0.9143
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.92      1.00      0.96        11
#            2       0.92      0.85      0.88        13
#            3       0.86      0.86      0.86         7
#
#     accuracy                           0.91        35
#    macro avg       0.92      0.93      0.92        35
# weighted avg       0.91      0.91      0.91        35

# %%
fn_plot_confusion_matrix(y_true, y_pred, class_labels)
