# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name: ______________________
# - PRN : ______________________
# - Date: ______________________

# %% [markdown]
# # Deep Neural Network
# ## Assignment A05
#
# ## Tensor Flow
# - Select number of layers
# - Select node in each of the layers
# - Choose activation function
# - multi-class - Fashion MNIST dataset (all 60000 images)
# - Implement one or more of following to achieve max accuracy.
#     - L1/ L2 Regularization
#     - Dropout
#     - Batch Normalization
#     - Early stopping
# - Save model

# %%
###-----------------
### Import Libraries
###-----------------
import os
import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,ConfusionMatrixDisplay
from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
inpDir = os.path.join('input')
outDir = '../output'
modelDir = '../models'
subDir = 'fashion_mnist'
altName = 'vanilla'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
###-----------------
### Hyper Parameters
###-----------------


BATCH_SIZE = 32 # mini batch size (number of rows)
TRAIN_SIZE  = int(18*BATCH_SIZE)
TEST_SIZE = 0.2

ALPHA = 0.001
EPOCHS = 100 # number of epochs
WEIGHT_DECAY = 0.001
PATIENCE = 20
LR_FACTOR  = 0.1
LR_PATIENCE = 5
MIN_LR = 1e-5

params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and [load the Fashion MNIST data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data) directly from TensorFlow:

# %%
train_df = pd.read_csv('../datasets/dnn_input/fashion_mnist/fashion-mnist_train.csv',header = 0)
test_df = pd.read_csv('../datasets/dnn_input/fashion_mnist/fashion-mnist_test.csv',header = 0)

# %% [markdown]
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
#class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_names = {0: 'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',
               5:'Sandal', 6: 'Shirt',7: 'Sneaker', 8:'Bag', 9: 'Ankle boot'}

# %%
def fn_plt_label(tr_df,ts_df):
    plt.figure()
    plt.subplot(1,2,1)
    ax = tr_df['label'].value_counts().plot(kind = 'bar',
                                          title = 'Train',
                                          color = 'Darkblue',
                                          alpha = 0.7)
    plt.subplot(1,2,2)
    
    ax = ts_df['label'].value_counts().plot(kind = 'bar',
                                          title = 'Test',
                                          color = 'Orange',
                                          alpha = 0.7)

# %%
fn_plt_label(train_df,test_df)

# %%
# sample data plot

plot_df = train_df.sample(n=BATCH_SIZE) # take 100 sample from the training set
fig = plt.figure(figsize=(15, 12)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # adjust

i = 0
for _, row in plot_df.iterrows(): # iterate through all rows of the dataframe
    i = i + 1
    image = row.values[1:].reshape(28, 28) # reshape row to a 28 x 28 matrix
    ax = fig.add_subplot(BATCH_SIZE//8, 8, (i), xticks=[], yticks=[]) 
    ax.imshow(image, cmap=plt.cm.binary, interpolation='nearest')
    ax.text(2, 4, str(row.iloc[0]), color='b', fontsize=14)
    ax.text(10, 25, class_names[row.iloc[0]], color='r', fontsize=10)

plt.show()

# %%
def split_features_label(row):
    feature = tf.reshape(row[1:],[28,28,1])
    label = row[0]
    return feature,label

# %% [markdown]
# <h1>Plotting dataset</h1>

# %%
tmp_ds = tf.data.Dataset.from_tensor_slices(train_df)
train_ds = tmp_ds.map(split_features_label)
train_ds = train_ds.batch(batch_size=BATCH_SIZE)

tmp_ds = tf.data.Dataset.from_tensor_slices(test_df)
test_ds = tmp_ds.map(split_features_label)
test_ds = test_ds.batch(batch_size=BATCH_SIZE)

# %%
# sample data plot

# plot_df = train_df.sample(n=BATCH_SIZE) # take 100 sample from the training set
fig = plt.figure(figsize=(15, 12)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # adjust

i = 0
for images,labels in train_ds.take(1):
    for i in range(BATCH_SIZE): # iterate through all rows of the dataframe
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[]) 
        ax.grid(False)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary)
        ax.text(2, 4, str(labels[i].numpy()), color='b', fontsize=14)
        ax.text(10, 25, class_names[labels[i].numpy()], color='r', fontsize=10)

plt.show()

# %% [markdown]
# <h1>rescaling</h1>

# %%
norm_layer = tf.keras.layers.Rescaling(1.0/255)
print(f'{images[0].numpy().min(),images[0].numpy().max()}')

norm_ds = train_ds.map(lambda x,y : (norm_layer(x),y))
images,lables = next(iter(norm_ds))
print(f'{images[0].numpy().min(),images[0].numpy().max()}')
# Out:
# (np.int64(0), np.int64(255))
# (np.float32(0.0), np.float32(1.0))

# %% [markdown]
# <h1>Convulation in action</h1>

# %%
input_shape = (1,6,6,1)
X = tf.random.normal(input_shape)
X.shape
sns.heatmap(X.numpy()[0,:,:,0],annot = True,fmt = '.2f', cmap = 'winter')
# Out:
# <Axes: >

# %%
y = tf.keras.layers.Conv2D(
                           1,3,
                           kernel_initializer=tf.constant_initializer(1.0),
                           use_bias = False,
                           activation = 'relu'
                          )(X)
y.shape
# Out:
# TensorShape([1, 4, 4, 1])

# %%
sns.heatmap(y.numpy()[0,:,:,0],
            annot = True,
            fmt = '.2f',
            cmap = 'Blues')
# Out:
# <Axes: >

# %%
max_pool_2d = tf.keras.layers.MaxPool2D()(y)

sns.heatmap(max_pool_2d.numpy()[0,:,:,0],
            annot = True,
            fmt = '.2f',
            cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# <h1>Build model </h1>

# %%
input_shape = (28,28,1)

regularizer = tf.keras.regularizers.L2(l2 = 0.001)




model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=input_shape))
model.add(tf.keras.layers.Rescaling(1.0/255))

#Set 1
model.add(tf.keras.layers.Conv2D(32,(3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #(28 * 28 * 32)
model.add(tf.keras.layers.MaxPool2D()) #(14*14*32)


#Set 2
model.add(tf.keras.layers.Conv2D(64,(3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #(12 * 12 * 64)
model.add(tf.keras.layers.MaxPool2D()) #(6*6*64)

#Set 3
model.add(tf.keras.layers.Conv2D(128,(3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #(4 * 4 * 128)
model.add(tf.keras.layers.Flatten())


model.add(tf.keras.layers.Dense(128,
                                kernel_regularizer=regularizer,
                                activation='relu'))
model.add(tf.keras.layers.Dense(10))


loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model.compile(optimizer = optimizer,
             loss = loss_fn,
             
             metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         802,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 896,906 (3.42 MB)
#  Trainable params: 896,906 (3.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#call backs

tb_callback = tf.keras .callbacks.TensorBoard(log_dir='logs')

es_callback = tf.keras.callbacks.EarlyStopping(monitor= 'val_loss',
                                               min_delta= 0,
                                              patience=PATIENCE,
                                              verbose = 1,
                                              restore_best_weights=True,
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
   monitor='val_loss',
    factor= LR_FACTOR,
    patience = LR_PATIENCE,
    verbose = 1,
    min_lr=1e-6
)

# %%
history = model.fit(train_ds,
         validation_data=test_ds,
         epochs= EPOCHS,
         callbacks=[es_callback,lr_callback])
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 15ms/step - accuracy: 0.7882 - loss: 0.8650 - val_accuracy: 0.8343 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8283 - loss: 0.6581 - val_accuracy: 0.8433 - val_loss: 0.6387 - learning_rate: 0.0010
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.8365 - loss: 0.6237 - val_accuracy: 0.8460 - val_loss: 0.6174 - learning_rate: 0.0010
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.8419 - loss: 0.6010 - val_accuracy: 0.8468 - val_loss: 0.6043 - learning_rate: 0.0010
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8456 - loss: 0.5841 - val_accuracy: 0.8496 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8494 - loss: 0.5706 - val_accuracy: 0.8501 - val_loss: 0.5807 - learning_rate: 0.0010
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8529 - loss: 0.5595 - val_accuracy: 0.8497 - val_loss: 0.5753 - learning_rate: 0.0010
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8548 - loss: 0.5509 - val_accuracy: 0.8513 - val_loss: 0.5618 - learning_rate: 0.0010
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 18ms/step - accuracy: 0.8565 - loss: 0.5440 - val_accuracy: 0.8514 - val_loss: 0.5585 - learning_rate: 0.0010
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8580 - loss: 0.5384 - val_accuracy: 0.8536 - val_loss: 0.5533 - learning_rate: 0.0010
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8592 - loss: 0.5337 - val_accuracy: 0.8541 - val_loss: 0.5494 - learning_rate: 0.0010
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8607 - loss: 0.5291 - val_accuracy: 0.8588 - val_loss: 0.5419 - learning_rate: 0.0010
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8611 - loss: 0.5251 - val_accuracy: 0.8560 - val_loss: 0.5415 - learning_rate: 0.0010
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8619 - loss: 0.5219 - val_accuracy: 0.8585 - val_loss: 0.5373 - learning_rate: 0.0010
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8625 - loss: 0.5185 - val_accuracy: 0.8574 - val_loss: 0.5381 - learning_rate: 0.0010
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8631 - loss: 0.5153 - val_accuracy: 0.8567 - val_loss: 0.5340 - learning_rate: 0.0010
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8639 - loss: 0.5124 - val_accuracy: 0.8590 - val_loss: 0.5272 - learning_rate: 0.0010
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8643 - loss: 0.5099 - val_accuracy: 0.8596 - val_loss: 0.5247 - learning_rate: 0.0010
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8652 - loss: 0.5077 - val_accuracy: 0.8611 - val_loss: 0.5206 - learning_rate: 0.0010
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8655 - loss: 0.5055 - val_accuracy: 0.8598 - val_loss: 0.5204 - learning_rate: 0.0010
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8659 - loss: 0.5031 - val_accuracy: 0.8605 - val_loss: 0.5158 - learning_rate: 0.0010
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8662 - loss: 0.5013 - val_accuracy: 0.8616 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8722 - loss: 0.4662 - val_accuracy: 0.8705 - val_loss: 0.4749 - learning_rate: 0.0010
# Epoch 56/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8719 - loss: 0.4656 - val_accuracy: 0.8697 - val_loss: 0.4759 - learning_rate: 0.0010
# Epoch 57/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8730 - loss: 0.4654 - val_accuracy: 0.8689 - val_loss: 0.4771 - learning_rate: 0.0010
# Epoch 58/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8723 - loss: 0.4651 - val_accuracy: 0.8707 - val_loss: 0.4744 - learning_rate: 0.0010
# Epoch 59/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8731 - loss: 0.4646 - val_accuracy: 0.8697 - val_loss: 0.4729 - learning_rate: 0.0010
# Epoch 60/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8731 - loss: 0.4636 - val_accuracy: 0.8722 - val_loss: 0.4735 - learning_rate: 0.0010
# Epoch 61/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8735 - loss: 0.4631 - val_accuracy: 0.8699 - val_loss: 0.4769 - learning_rate: 0.0010
# Epoch 62/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8730 - loss: 0.4633 - val_accuracy: 0.8716 - val_loss: 0.4769 - learning_rate: 0.0010
# Epoch 63/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8731 - loss: 0.4624 - val_accuracy: 0.8681 - val_loss: 0.4760 - learning_rate: 0.0010
# Epoch 64/100
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8734 - loss: 0.4598
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8736 - loss: 0.4618 - val_accuracy: 0.8687 - val_loss: 0.4754 - learning_rate: 0.0010
# Epoch 65/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8885 - loss: 0.4182 - val_accuracy: 0.8851 - val_loss: 0.4209 - learning_rate: 1.0000e-04
# Epoch 66/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8904 - loss: 0.4084 - val_accuracy: 0.8861 - val_loss: 0.4159 - learning_rate: 1.0000e-04
# Epoch 67/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8916 - loss: 0.4038 - val_accuracy: 0.8873 - val_loss: 0.4126 - learning_rate: 1.0000e-04
# Epoch 68/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8929 - loss: 0.4007 - val_accuracy: 0.8875 - val_loss: 0.4110 - learning_rate: 1.0000e-04
# Epoch 69/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8939 - loss: 0.3984 - val_accuracy: 0.8879 - val_loss: 0.4097 - learning_rate: 1.0000e-04
# Epoch 70/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8944 - loss: 0.3965 - val_accuracy: 0.8886 - val_loss: 0.4085 - learning_rate: 1.0000e-04
# Epoch 71/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8947 - loss: 0.3950 - val_accuracy: 0.8879 - val_loss: 0.4074 - learning_rate: 1.0000e-04
# Epoch 72/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8950 - loss: 0.3937 - val_accuracy: 0.8882 - val_loss: 0.4066 - learning_rate: 1.0000e-04
# Epoch 73/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.8953 - loss: 0.3925 - val_accuracy: 0.8886 - val_loss: 0.4056 - learning_rate: 1.0000e-04
# Epoch 74/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8954 - loss: 0.3915 - val_accuracy: 0.8885 - val_loss: 0.4048 - learning_rate: 1.0000e-04
# Epoch 75/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8957 - loss: 0.3907 - val_accuracy: 0.8888 - val_loss: 0.4047 - learning_rate: 1.0000e-04
# Epoch 76/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8960 - loss: 0.3899 - val_accuracy: 0.8888 - val_loss: 0.4042 - learning_rate: 1.0000e-04
# Epoch 77/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8963 - loss: 0.3893 - val_accuracy: 0.8894 - val_loss: 0.4036 - learning_rate: 1.0000e-04
# Epoch 78/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8960 - loss: 0.3886 - val_accuracy: 0.8895 - val_loss: 0.4034 - learning_rate: 1.0000e-04
# Epoch 79/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8964 - loss: 0.3880 - val_accuracy: 0.8898 - val_loss: 0.4028 - learning_rate: 1.0000e-04
# Epoch 80/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8969 - loss: 0.3875 - val_accuracy: 0.8899 - val_loss: 0.4027 - learning_rate: 1.0000e-04
# Epoch 81/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8970 - loss: 0.3870 - val_accuracy: 0.8894 - val_loss: 0.4021 - learning_rate: 1.0000e-04
# Epoch 82/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.8972 - loss: 0.3866 - val_accuracy: 0.8901 - val_loss: 0.4017 - learning_rate: 1.0000e-04
# Epoch 83/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.8976 - loss: 0.3861 - val_accuracy: 0.8901 - val_loss: 0.4015 - learning_rate: 1.0000e-04
# Epoch 84/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8974 - loss: 0.3857 - val_accuracy: 0.8900 - val_loss: 0.4014 - learning_rate: 1.0000e-04
# Epoch 85/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 16ms/step - accuracy: 0.8978 - loss: 0.3853 - val_accuracy: 0.8902 - val_loss: 0.4009 - learning_rate: 1.0000e-04
# Epoch 86/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.8982 - loss: 0.3849 - val_accuracy: 0.8898 - val_loss: 0.4010 - learning_rate: 1.0000e-04
# Epoch 87/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.8978 - loss: 0.3845 - val_accuracy: 0.8904 - val_loss: 0.4004 - learning_rate: 1.0000e-04
# Epoch 88/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 46s 25ms/step - accuracy: 0.8981 - loss: 0.3842 - val_accuracy: 0.8902 - val_loss: 0.4003 - learning_rate: 1.0000e-04
# Epoch 89/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.8980 - loss: 0.3838 - val_accuracy: 0.8908 - val_loss: 0.3998 - learning_rate: 1.0000e-04
# Epoch 90/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - accuracy: 0.8981 - loss: 0.3835 - val_accuracy: 0.8904 - val_loss: 0.4000 - learning_rate: 1.0000e-04
# Epoch 91/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.8982 - loss: 0.3833 - val_accuracy: 0.8904 - val_loss: 0.3998 - learning_rate: 1.0000e-04
# Epoch 92/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 47s 25ms/step - accuracy: 0.8981 - loss: 0.3829 - val_accuracy: 0.8901 - val_loss: 0.3997 - learning_rate: 1.0000e-04
# Epoch 93/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - accuracy: 0.8982 - loss: 0.3827 - val_accuracy: 0.8902 - val_loss: 0.3997 - learning_rate: 1.0000e-04
# Epoch 94/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 25ms/step - accuracy: 0.8983 - loss: 0.3824 - val_accuracy: 0.8905 - val_loss: 0.3994 - learning_rate: 1.0000e-04
# Epoch 95/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.8987 - loss: 0.3822 - val_accuracy: 0.8902 - val_loss: 0.3988 - learning_rate: 1.0000e-04
# Epoch 96/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.8987 - loss: 0.3819 - val_accuracy: 0.8906 - val_loss: 0.3988 - learning_rate: 1.0000e-04
# Epoch 97/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.8986 - loss: 0.3816 - val_accuracy: 0.8911 - val_loss: 0.3988 - learning_rate: 1.0000e-04
# Epoch 98/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 22ms/step - accuracy: 0.8986 - loss: 0.3814 - val_accuracy: 0.8915 - val_loss: 0.3987 - learning_rate: 1.0000e-04
# Epoch 99/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.8987 - loss: 0.3811 - val_accuracy: 0.8910 - val_loss: 0.3986 - learning_rate: 1.0000e-04
# Epoch 100/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - accuracy: 0.8989 - loss: 0.3809 - val_accuracy: 0.8911 - val_loss: 0.3986 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 99.

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
y_train = tf.concat([y for x, y in train_ds], axis=0).numpy()
print(y_train.shape)
# Out:
# (60000,)

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_train, y_pred):.5f}')
print(classification_report(y_train, y_pred))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step
# Accuracy: 0.89943
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85      6000
#            1       0.99      0.98      0.98      6000
#            2       0.85      0.83      0.84      6000
#            3       0.86      0.93      0.89      6000
#            4       0.81      0.86      0.84      6000
#            5       0.98      0.96      0.97      6000
#            6       0.76      0.69      0.73      6000
#            7       0.95      0.94      0.95      6000
#            8       0.97      0.98      0.98      6000
#            9       0.95      0.98      0.96      6000
#
#     accuracy                           0.90     60000
#    macro avg       0.90      0.90      0.90     60000
# weighted avg       0.90      0.90      0.90     60000

# %%
fn_plot_confusion_matrix(y_train, y_pred, class_names)

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in train_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0).numpy()
print(y_test.shape)
# Out:
# (10000,)

# %%
yhat = model.predict(test_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_test, y_pred):.5f}')
print(classification_report(y_test, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# Accuracy: 0.89100
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      1000
#            1       0.98      0.97      0.98      1000
#            2       0.87      0.82      0.84      1000
#            3       0.87      0.93      0.90      1000
#            4       0.81      0.87      0.84      1000
#            5       0.97      0.95      0.96      1000
#            6       0.74      0.67      0.70      1000
#            7       0.95      0.92      0.93      1000
#            8       0.96      0.97      0.97      1000
#            9       0.93      0.97      0.95      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
fn_plot_confusion_matrix(y_test, y_pred, class_names)

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in test_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Make Prediction</h1>

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis = 1)
print(f'Accuracy : {accuracy_score(y_train,y_predf}')
print(classification_report(y_train,y_pred))
# Out:
#   Cell In[31], line 3
#     print(f'Accuracy : {accuracy_score(y_train,y_predf}')
#                                                       ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('
