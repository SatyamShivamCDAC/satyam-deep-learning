# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Your Name and PRN:
# - Name: ______________________
# - PRN : ______________________
# - Date: ______________________

# %% [markdown]
# # Deep Neural Network
# ## Assignment A05
#
# ## Tensor Flow
# - Select number of layers
# - Select node in each of the layers
# - Choose activation function
# - multi-class - Fashion MNIST dataset (all 60000 images)
# - Implement one or more of following to achieve max accuracy.
#     - L1/ L2 Regularization
#     - Dropout
#     - Batch Normalization
#     - Early stopping
# - Save model

# %%
###-----------------
### Import Libraries
###-----------------
import os
import time
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,ConfusionMatrixDisplay
from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###-----------------
### Global Variables
###-----------------
inpDir = os.path.join('input')
outDir = '../output'
modelDir = '../models'
subDir = 'fashion_mnist'
altName = 'vanilla'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible results
tf.random.set_seed(RANDOM_STATE)

# parameters for Matplotlib
params = {'legend.fontsize': 'large',
          'figure.figsize': (15, 8),
          'axes.labelsize': 'large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'
         }

CMAP = 'brg' # plt.cm.Spectral

plt.rcParams.update(params)

# %%
###-----------------
### Hyper Parameters
###-----------------


BATCH_SIZE = 32 # mini batch size (number of rows)
TRAIN_SIZE  = int(18*BATCH_SIZE)
TEST_SIZE = 0.2

ALPHA = 0.001
EPOCHS = 100 # number of epochs
WEIGHT_DECAY = 0.001
PATIENCE = 20
LR_FACTOR  = 0.1
LR_PATIENCE = 5
MIN_LR = 1e-5

params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 5),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

# %% [markdown]
# ## Load Fashion MNIST dataset

# %% [markdown]
# This guide uses the [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen here:
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>Figure 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST samples</a> (by Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Fashion MNIST is intended as a drop-in replacement for the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset—often used as the "Hello, World" of machine learning programs for computer vision. The MNIST dataset contains images of handwritten digits (0, 1, 2, etc.) in a format identical to that of the articles of clothing you'll use here.
#
# This guide uses Fashion MNIST for variety, and because it's a slightly more challenging problem than regular MNIST. Both datasets are relatively small and are used to verify that an algorithm works as expected. They're good starting points to test and debug code.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and [load the Fashion MNIST data](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data) directly from TensorFlow:

# %%
train_df = pd.read_csv('../datasets/dnn_input/fashion_mnist/fashion-mnist_train.csv',header = 0)
test_df = pd.read_csv('../datasets/dnn_input/fashion_mnist/fashion-mnist_test.csv',header = 0)

# %% [markdown]
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
#class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
#               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

class_names = {0: 'T-shirt/top',1:'Trouser',2:'Pullover',3:'Dress',4:'Coat',
               5:'Sandal', 6: 'Shirt',7: 'Sneaker', 8:'Bag', 9: 'Ankle boot'}

# %%
def fn_plt_label(tr_df,ts_df):
    plt.figure()
    plt.subplot(1,2,1)
    ax = tr_df['label'].value_counts().plot(kind = 'bar',
                                          title = 'Train',
                                          color = 'Darkblue',
                                          alpha = 0.7)
    plt.subplot(1,2,2)
    
    ax = ts_df['label'].value_counts().plot(kind = 'bar',
                                          title = 'Test',
                                          color = 'Orange',
                                          alpha = 0.7)

# %%
fn_plt_label(train_df,test_df)

# %%
# sample data plot

plot_df = train_df.sample(n=BATCH_SIZE) # take 100 sample from the training set
fig = plt.figure(figsize=(15, 12)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # adjust

i = 0
for _, row in plot_df.iterrows(): # iterate through all rows of the dataframe
    i = i + 1
    image = row.values[1:].reshape(28, 28) # reshape row to a 28 x 28 matrix
    ax = fig.add_subplot(BATCH_SIZE//8, 8, (i), xticks=[], yticks=[]) 
    ax.imshow(image, cmap=plt.cm.binary, interpolation='nearest')
    ax.text(2, 4, str(row.iloc[0]), color='b', fontsize=14)
    ax.text(10, 25, class_names[row.iloc[0]], color='r', fontsize=10)

plt.show()

# %%
def split_features_label(row):
    feature = tf.reshape(row[1:],[28,28,1])
    label = row[0]
    return feature,label

# %% [markdown]
# <h1>Plotting dataset</h1>

# %%
tmp_ds = tf.data.Dataset.from_tensor_slices(train_df)
train_ds = tmp_ds.map(split_features_label)
train_ds = train_ds.batch(batch_size=BATCH_SIZE)

tmp_ds = tf.data.Dataset.from_tensor_slices(test_df)
test_ds = tmp_ds.map(split_features_label)
test_ds = test_ds.batch(batch_size=BATCH_SIZE)

# %%
# sample data plot

# plot_df = train_df.sample(n=BATCH_SIZE) # take 100 sample from the training set
fig = plt.figure(figsize=(15, 12)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05) # adjust

i = 0
for images,labels in train_ds.take(1):
    for i in range(BATCH_SIZE): # iterate through all rows of the dataframe
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[]) 
        ax.grid(False)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary)
        ax.text(2, 4, str(labels[i].numpy()), color='b', fontsize=14)
        ax.text(10, 25, class_names[labels[i].numpy()], color='r', fontsize=10)

plt.show()

# %% [markdown]
# <h1>rescaling</h1>

# %%
norm_layer = tf.keras.layers.Rescaling(1.0/255)
print(f'{images[0].numpy().min(),images[0].numpy().max()}')

norm_ds = train_ds.map(lambda x,y : (norm_layer(x),y))
images,lables = next(iter(norm_ds))
print(f'{images[0].numpy().min(),images[0].numpy().max()}')
# Out:
# (np.int64(0), np.int64(255))
# (np.float32(0.0), np.float32(1.0))

# %% [markdown]
# <h1>Convulation in action</h1>

# %%
input_shape = (1,6,6,1)
X = tf.random.normal(input_shape)
X.shape
sns.heatmap(X.numpy()[0,:,:,0],annot = True,fmt = '.2f', cmap = 'winter')
# Out:
# <Axes: >

# %%
y = tf.keras.layers.Conv2D(
                           1,3,
                           kernel_initializer=tf.constant_initializer(1.0),
                           use_bias = False,
                           activation = 'relu'
                          )(X)
y.shape
# Out:
# TensorShape([1, 4, 4, 1])

# %%
sns.heatmap(y.numpy()[0,:,:,0],
            annot = True,
            fmt = '.2f',
            cmap = 'Blues')
# Out:
# <Axes: >

# %%
max_pool_2d = tf.keras.layers.MaxPool2D()(y)

sns.heatmap(max_pool_2d.numpy()[0,:,:,0],
            annot = True,
            fmt = '.2f',
            cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# <h1>Build model </h1>

# %%
input_shape = (28,28,1)

regularizer = tf.keras.regularizers.L2(l2 = 0.001)
dor1 = 0.3
dor2 = 0.3
dor3 = 0.3
dor4 = 0.3




model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=input_shape))
model.add(tf.keras.layers.Rescaling(1.0/255))

#Set 1
model.add(tf.keras.layers.Conv2D(32,(3,3),padding='same',
                                 # kernel_regularizer=regularizer,
                                 # activation='relu'
                                )) #(28 * 28 * 32)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.MaxPool2D()) #(14*14*32)
model.add(tf.keras.layers.Dropout(dor1))

#Set 2
model.add(tf.keras.layers.Conv2D(64,(3,3),padding='same',
                                 # kernel_regularizer=regularizer,
                                 # activation='relu'
                                )) #(12 * 12 * 64)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.MaxPool2D()) #(14*14*32)
model.add(tf.keras.layers.Dropout(dor2))

#Set 3
model.add(tf.keras.layers.Conv2D(128,(3,3),padding='same',
                                 # kernel_regularizer=regularizer,
                                 # activation='relu'
                                )) #(4 * 4 * 128)
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(dor3))

model.add(tf.keras.layers.Flatten())


model.add(tf.keras.layers.Dense(128,
                                # kernel_regularizer=regularizer,
                                # activation='relu'
                               ))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.Dropout(dor4))

model.add(tf.keras.layers.Dense(10))


loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model.compile(optimizer = optimizer,
             loss = loss_fn,
             
             metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 28, 28, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 28, 28, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 7, 7, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 7, 7, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         802,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 898,314 (3.43 MB)
#  Trainable params: 897,610 (3.42 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
#call backs

tb_callback = tf.keras .callbacks.TensorBoard(log_dir='logs')

es_callback = tf.keras.callbacks.EarlyStopping(monitor= 'val_loss',
                                               min_delta= 0,
                                              patience=PATIENCE,
                                              verbose = 1,
                                              restore_best_weights=True,
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
   monitor='val_loss',
    factor= LR_FACTOR,
    patience = LR_PATIENCE,
    verbose = 1,
    min_lr=1e-6
)

# %%
history = model.fit(train_ds,
         validation_data=test_ds,
         epochs= EPOCHS,
         callbacks=[es_callback,lr_callback])
# Out:
# Epoch 1/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 104s 49ms/step - accuracy: 0.8297 - loss: 0.4751 - val_accuracy: 0.8895 - val_loss: 0.3074 - learning_rate: 0.0010
# Epoch 2/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 92s 49ms/step - accuracy: 0.8775 - loss: 0.3385 - val_accuracy: 0.9075 - val_loss: 0.2527 - learning_rate: 0.0010
# Epoch 3/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 93s 49ms/step - accuracy: 0.8891 - loss: 0.3030 - val_accuracy: 0.8962 - val_loss: 0.2772 - learning_rate: 0.0010
# Epoch 4/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 91s 48ms/step - accuracy: 0.8969 - loss: 0.2804 - val_accuracy: 0.8931 - val_loss: 0.2809 - learning_rate: 0.0010
# Epoch 5/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 72s 38ms/step - accuracy: 0.9023 - loss: 0.2635 - val_accuracy: 0.9023 - val_loss: 0.2587 - learning_rate: 0.0010
# Epoch 6/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 88s 47ms/step - accuracy: 0.9080 - loss: 0.2480 - val_accuracy: 0.9196 - val_loss: 0.2174 - learning_rate: 0.0010
# Epoch 7/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 148s 50ms/step - accuracy: 0.9122 - loss: 0.2367 - val_accuracy: 0.9072 - val_loss: 0.2489 - learning_rate: 0.0010
# Epoch 8/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 71s 38ms/step - accuracy: 0.9151 - loss: 0.2290 - val_accuracy: 0.9034 - val_loss: 0.2558 - learning_rate: 0.0010
# Epoch 9/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9181 - loss: 0.2217 - val_accuracy: 0.9175 - val_loss: 0.2249 - learning_rate: 0.0010
# Epoch 10/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9209 - loss: 0.2117 - val_accuracy: 0.8996 - val_loss: 0.2736 - learning_rate: 0.0010
# Epoch 11/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9229 - loss: 0.2056 - val_accuracy: 0.9294 - val_loss: 0.1915 - learning_rate: 0.0010
# Epoch 12/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.9251 - loss: 0.2009 - val_accuracy: 0.9184 - val_loss: 0.2281 - learning_rate: 0.0010
# Epoch 13/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9277 - loss: 0.1937 - val_accuracy: 0.9294 - val_loss: 0.1963 - learning_rate: 0.0010
# Epoch 14/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9297 - loss: 0.1884 - val_accuracy: 0.9288 - val_loss: 0.1918 - learning_rate: 0.0010
# Epoch 15/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9296 - loss: 0.1843 - val_accuracy: 0.9227 - val_loss: 0.2082 - learning_rate: 0.0010
# Epoch 16/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9339 - loss: 0.1769
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9329 - loss: 0.1789 - val_accuracy: 0.9270 - val_loss: 0.2002 - learning_rate: 0.0010
# Epoch 17/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9391 - loss: 0.1596 - val_accuracy: 0.9372 - val_loss: 0.1743 - learning_rate: 1.0000e-04
# Epoch 18/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9428 - loss: 0.1532 - val_accuracy: 0.9370 - val_loss: 0.1735 - learning_rate: 1.0000e-04
# Epoch 19/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9443 - loss: 0.1485 - val_accuracy: 0.9387 - val_loss: 0.1716 - learning_rate: 1.0000e-04
# Epoch 20/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9455 - loss: 0.1473 - val_accuracy: 0.9374 - val_loss: 0.1767 - learning_rate: 1.0000e-04
# Epoch 21/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - accuracy: 0.9465 - loss: 0.1445 - val_accuracy: 0.9397 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 22/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - accuracy: 0.9470 - loss: 0.1424 - val_accuracy: 0.9401 - val_loss: 0.1716 - learning_rate: 1.0000e-04
# Epoch 23/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.9477 - loss: 0.1414 - val_accuracy: 0.9403 - val_loss: 0.1692 - learning_rate: 1.0000e-04
# Epoch 24/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9473 - loss: 0.1411 - val_accuracy: 0.9392 - val_loss: 0.1733 - learning_rate: 1.0000e-04
# Epoch 25/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.9481 - loss: 0.1402 - val_accuracy: 0.9410 - val_loss: 0.1674 - learning_rate: 1.0000e-04
# Epoch 26/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9477 - loss: 0.1378 - val_accuracy: 0.9391 - val_loss: 0.1756 - learning_rate: 1.0000e-04
# Epoch 27/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9504 - loss: 0.1350 - val_accuracy: 0.9405 - val_loss: 0.1723 - learning_rate: 1.0000e-04
# Epoch 28/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9494 - loss: 0.1352 - val_accuracy: 0.9413 - val_loss: 0.1673 - learning_rate: 1.0000e-04
# Epoch 29/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9508 - loss: 0.1317 - val_accuracy: 0.9392 - val_loss: 0.1785 - learning_rate: 1.0000e-04
# Epoch 30/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9523 - loss: 0.1301
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9519 - loss: 0.1303 - val_accuracy: 0.9395 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Epoch 31/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9514 - loss: 0.1292 - val_accuracy: 0.9432 - val_loss: 0.1656 - learning_rate: 1.0000e-05
# Epoch 32/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9531 - loss: 0.1276 - val_accuracy: 0.9421 - val_loss: 0.1656 - learning_rate: 1.0000e-05
# Epoch 33/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9514 - loss: 0.1293 - val_accuracy: 0.9432 - val_loss: 0.1657 - learning_rate: 1.0000e-05
# Epoch 34/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9521 - loss: 0.1281 - val_accuracy: 0.9427 - val_loss: 0.1658 - learning_rate: 1.0000e-05
# Epoch 35/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 29ms/step - accuracy: 0.9523 - loss: 0.1270 - val_accuracy: 0.9426 - val_loss: 0.1651 - learning_rate: 1.0000e-05
# Epoch 36/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9527 - loss: 0.1284 - val_accuracy: 0.9426 - val_loss: 0.1653 - learning_rate: 1.0000e-05
# Epoch 37/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9509 - loss: 0.1308 - val_accuracy: 0.9421 - val_loss: 0.1659 - learning_rate: 1.0000e-05
# Epoch 38/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9519 - loss: 0.1290 - val_accuracy: 0.9420 - val_loss: 0.1662 - learning_rate: 1.0000e-05
# Epoch 39/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9511 - loss: 0.1290 - val_accuracy: 0.9421 - val_loss: 0.1658 - learning_rate: 1.0000e-05
# Epoch 40/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9520 - loss: 0.1300
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9521 - loss: 0.1276 - val_accuracy: 0.9420 - val_loss: 0.1655 - learning_rate: 1.0000e-05
# Epoch 41/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9528 - loss: 0.1262 - val_accuracy: 0.9423 - val_loss: 0.1658 - learning_rate: 1.0000e-06
# Epoch 42/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9524 - loss: 0.1292 - val_accuracy: 0.9425 - val_loss: 0.1660 - learning_rate: 1.0000e-06
# Epoch 43/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9528 - loss: 0.1278 - val_accuracy: 0.9423 - val_loss: 0.1658 - learning_rate: 1.0000e-06
# Epoch 44/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9518 - loss: 0.1283 - val_accuracy: 0.9421 - val_loss: 0.1662 - learning_rate: 1.0000e-06
# Epoch 45/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9525 - loss: 0.1261
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9524 - loss: 0.1267 - val_accuracy: 0.9423 - val_loss: 0.1660 - learning_rate: 1.0000e-06
# Epoch 46/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9515 - loss: 0.1286 - val_accuracy: 0.9423 - val_loss: 0.1662 - learning_rate: 1.0000e-06
# Epoch 47/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9514 - loss: 0.1278 - val_accuracy: 0.9424 - val_loss: 0.1661 - learning_rate: 1.0000e-06
# Epoch 48/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9534 - loss: 0.1265 - val_accuracy: 0.9422 - val_loss: 0.1661 - learning_rate: 1.0000e-06
# Epoch 49/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9534 - loss: 0.1256 - val_accuracy: 0.9422 - val_loss: 0.1663 - learning_rate: 1.0000e-06
# Epoch 50/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9521 - loss: 0.1267 - val_accuracy: 0.9423 - val_loss: 0.1664 - learning_rate: 1.0000e-06
# Epoch 51/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9527 - loss: 0.1274 - val_accuracy: 0.9423 - val_loss: 0.1662 - learning_rate: 1.0000e-06
# Epoch 52/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9524 - loss: 0.1275 - val_accuracy: 0.9423 - val_loss: 0.1662 - learning_rate: 1.0000e-06
# Epoch 53/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 28ms/step - accuracy: 0.9523 - loss: 0.1265 - val_accuracy: 0.9424 - val_loss: 0.1661 - learning_rate: 1.0000e-06
# Epoch 54/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.9519 - loss: 0.1292 - val_accuracy: 0.9423 - val_loss: 0.1663 - learning_rate: 1.0000e-06
# Epoch 55/100
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9525 - loss: 0.1263 - val_accuracy: 0.9422 - val_loss: 0.1661 - learning_rate: 1.0000e-06
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 35.

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
y_train = tf.concat([y for x, y in train_ds], axis=0).numpy()
print(y_train.shape)
# Out:
# (60000,)

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_train, y_pred):.5f}')
print(classification_report(y_train, y_pred))
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step
# Accuracy: 0.97127
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      6000
#            1       1.00      1.00      1.00      6000
#            2       0.96      0.95      0.95      6000
#            3       0.97      0.98      0.97      6000
#            4       0.95      0.95      0.95      6000
#            5       1.00      1.00      1.00      6000
#            6       0.91      0.91      0.91      6000
#            7       0.98      0.99      0.99      6000
#            8       1.00      1.00      1.00      6000
#            9       0.99      0.99      0.99      6000
#
#     accuracy                           0.97     60000
#    macro avg       0.97      0.97      0.97     60000
# weighted avg       0.97      0.97      0.97     60000

# %%
fn_plot_confusion_matrix(y_train, y_pred, class_names)

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in train_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0).numpy()
print(y_test.shape)
# Out:
# (10000,)

# %%
yhat = model.predict(test_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_test, y_pred):.5f}')
print(classification_report(y_test, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Accuracy: 0.94260
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89      1000
#            1       1.00      1.00      1.00      1000
#            2       0.93      0.90      0.91      1000
#            3       0.95      0.97      0.96      1000
#            4       0.91      0.92      0.91      1000
#            5       0.99      0.98      0.99      1000
#            6       0.82      0.83      0.83      1000
#            7       0.97      0.97      0.97      1000
#            8       0.99      0.99      0.99      1000
#            9       0.97      0.98      0.97      1000
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
fn_plot_confusion_matrix(y_test, y_pred, class_names)

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in test_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Make Prediction</h1>

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis = 1)
print(f'Accuracy : {accuracy_score(y_train,y_predf}')
print(classification_report(y_train,y_pred))
# Out:
#   Cell In[31], line 3
#     print(f'Accuracy : {accuracy_score(y_train,y_predf}')
#                                                       ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('
