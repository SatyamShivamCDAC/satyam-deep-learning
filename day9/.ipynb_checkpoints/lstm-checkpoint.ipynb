# %%
###-----------------
### Import libraries
###-----------------

from pathlib import Path  # Import Path for file system path operations and management
import numpy as np  # Import NumPy for numerical computations and array operations
import pandas as pd  # Import Pandas for data manipulation and analysis with DataFrames
import matplotlib.pyplot as plt  # Import Matplotlib for creating static, interactive visualizations
import seaborn as sns  # Import Seaborn for statistical data visualization built on Matplotlib

from sklearn.model_selection import train_test_split  # Import function to split dataset into training and testing subsets
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score, mean_squared_error,r2_score  # Import function to calculate various metric

from collections.abc import Callable  # Type hinting callable objects/functions
from typing import Literal  # Literal type hints to restrict variable values

from sklearn.preprocessing import MinMaxScaler  # Import for standardizing features (zero mean, unit variance)

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix, fn_plot_label# Custom utility

import tensorflow as tf

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = Path('..') / '..' / 'input'
outDir = Path('..') / 'output'
modelDir = Path('..') / 'models'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

TEST_SIZE = 0.2

ALPHA = 0.001
EPOCHS = 100# number of cycles to run
PATIENCE = 20
LR_PATIENCE = 15
FACTOR_LR = 0.1
BATCH_SIZE = 32 # inline of Training Rows being 60000
IMG_HEIGHT = 190
IMG_WIDTH = 190
LR_FACTOR  = 0.1
MIN_LR = 1e-5

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,10),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# <h1>
#     Getting Data
# </h1>

# %%
data_df = pd.read_csv('../datasets/dnn_input/housing/household_power_consumption.txt',
                      sep=';',
                      na_values=['nan','?'])
data_df
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        16/12/2006  17:24:00                4.216                  0.418
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 4        16/12/2006  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 0         234.84              18.4             0.0             1.0
# 1         233.63              23.0             0.0             1.0
# 2         233.29              23.0             0.0             2.0
# 3         233.74              23.0             0.0             1.0
# 4         235.68              15.8             0.0             1.0
# ...          ...               ...             ...             ...
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3
# 0                  17.0
# 1                  16.0
# 2                  17.0
# 3                  17.0
# 4                  17.0
# ...                 ...
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# 2075258             0.0
#
# [2075259 rows x 9 columns]

# %%
data_df['dt'] = pd.to_datetime(data_df['Date'] + ' ' + data_df['Time'],dayfirst=True)
data_df = data_df.set_index('dt',drop=True)
data_df = data_df.drop(['Date','Time'],axis = 1)
data_df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# dt
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# dt
# 2006-12-16 17:24:00            17.0
# 2006-12-16 17:25:00            16.0
# 2006-12-16 17:26:00            17.0
# 2006-12-16 17:27:00            17.0
# 2006-12-16 17:28:00            17.0

# %%
data_df = data_df.fillna(data_df.mean())
df_resample = data_df.resample('h').mean()
df_resample.head()
# Out:
#                      Global_active_power  Global_reactive_power     Voltage  \
# dt
# 2006-12-16 17:00:00             4.222889               0.229000  234.643889
# 2006-12-16 18:00:00             3.632200               0.080033  234.580167
# 2006-12-16 19:00:00             3.400233               0.085233  233.232500
# 2006-12-16 20:00:00             3.268567               0.075100  234.071500
# 2006-12-16 21:00:00             3.056467               0.076667  237.158667
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:00:00         18.100000             0.0        0.527778
# 2006-12-16 18:00:00         15.600000             0.0        6.716667
# 2006-12-16 19:00:00         14.503333             0.0        1.433333
# 2006-12-16 20:00:00         13.916667             0.0        0.000000
# 2006-12-16 21:00:00         13.046667             0.0        0.416667
#
#                      Sub_metering_3
# dt
# 2006-12-16 17:00:00       16.861111
# 2006-12-16 18:00:00       16.866667
# 2006-12-16 19:00:00       16.683333
# 2006-12-16 20:00:00       16.783333
# 2006-12-16 21:00:00       17.216667

# %%
df_resample['target'] = df_resample['Global_active_power'].shift(-1)
df_resample = df_resample.dropna()
df_resample.head()
# Out:
#                      Global_active_power  Global_reactive_power     Voltage  \
# dt
# 2006-12-16 17:00:00             4.222889               0.229000  234.643889
# 2006-12-16 18:00:00             3.632200               0.080033  234.580167
# 2006-12-16 19:00:00             3.400233               0.085233  233.232500
# 2006-12-16 20:00:00             3.268567               0.075100  234.071500
# 2006-12-16 21:00:00             3.056467               0.076667  237.158667
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# dt
# 2006-12-16 17:00:00         18.100000             0.0        0.527778
# 2006-12-16 18:00:00         15.600000             0.0        6.716667
# 2006-12-16 19:00:00         14.503333             0.0        1.433333
# 2006-12-16 20:00:00         13.916667             0.0        0.000000
# 2006-12-16 21:00:00         13.046667             0.0        0.416667
#
#                      Sub_metering_3    target
# dt
# 2006-12-16 17:00:00       16.861111  3.632200
# 2006-12-16 18:00:00       16.866667  3.400233
# 2006-12-16 19:00:00       16.683333  3.268567
# 2006-12-16 20:00:00       16.783333  3.056467
# 2006-12-16 21:00:00       17.216667  2.200133

# %%
split = 365*24

train_df = df_resample.iloc[:split]
test_df = df_resample.iloc[split:]

df_resample.shape,train_df.shape,test_df.shape
# Out:
# ((34588, 8), (8760, 8), (25828, 8))

# %%
y_train = train_df['target'].to_numpy()
y_test = test_df['target'].to_numpy()

train_feat_df = train_df.drop('target',axis = 1)
test_feat_df = test_df.drop('target',axis = 1)


train_feat_df.shape,test_feat_df.shape
# Out:
# ((8760, 7), (25828, 7))

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train_feat_df)
X_test = scaler.transform(test_feat_df)

X_train.shape,X_test.shape
# Out:
# ((8760, 7), (25828, 7))

# %%
#converting Xdatas t -> batch * timestamp * features

X_train = X_train.reshape(X_train.shape[0],1,X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0],1,X_test.shape[1])

X_train.shape,X_test.shape
# Out:
# ((8760, 1, 7), (25828, 1, 7))

# %% [markdown]
# <h1>Model Declaration</h1>

# %%
model = tf.keras.Sequential()

init = tf.keras.initializers.HeNormal()

model.add(tf.keras.Input(shape=(X_train.shape[1],X_train.shape[2])))
model.add(tf.keras.layers.LSTM(512,activation='tanh',kernel_initializer=init))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(128,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(1,activation = 'linear'))

# %%
metrics =tf.keras.metrics.RootMeanSquaredError()#metrics
loss_fn = tf.keras.losses.MeanSquaredError() #loss function
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA) #optimizer

# %% [markdown]
# <h1>Training Model</h1>

# %%
metrics =tf.keras.metrics.RootMeanSquaredError()#metrics
loss_fn = tf.keras.losses.MeanSquaredError() #loss function
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA) #optimizer

# %%
model.compile(optimizer = optimizer,
             loss = loss_fn,
             metrics = [metrics])

# %%
history = model.fit(X_train,y_train,
                    validation_data=[X_test,y_test],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS)
# Out:
# Epoch 1/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.4833 - root_mean_squared_error: 0.6952 - val_loss: 0.3550 - val_root_mean_squared_error: 0.5958
# Epoch 2/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4582 - root_mean_squared_error: 0.6769 - val_loss: 0.3471 - val_root_mean_squared_error: 0.5891
# Epoch 3/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4446 - root_mean_squared_error: 0.6668 - val_loss: 0.3489 - val_root_mean_squared_error: 0.5907
# Epoch 4/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4445 - root_mean_squared_error: 0.6667 - val_loss: 0.3521 - val_root_mean_squared_error: 0.5934
# Epoch 5/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4429 - root_mean_squared_error: 0.6655 - val_loss: 0.3541 - val_root_mean_squared_error: 0.5951
# Epoch 6/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4414 - root_mean_squared_error: 0.6644 - val_loss: 0.3494 - val_root_mean_squared_error: 0.5911
# Epoch 7/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4382 - root_mean_squared_error: 0.6620 - val_loss: 0.3481 - val_root_mean_squared_error: 0.5900
# Epoch 8/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4386 - root_mean_squared_error: 0.6623 - val_loss: 0.3467 - val_root_mean_squared_error: 0.5888
# Epoch 9/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4329 - root_mean_squared_error: 0.6579 - val_loss: 0.3461 - val_root_mean_squared_error: 0.5883
# Epoch 10/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4334 - root_mean_squared_error: 0.6584 - val_loss: 0.3440 - val_root_mean_squared_error: 0.5865
# Epoch 11/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4299 - root_mean_squared_error: 0.6557 - val_loss: 0.3467 - val_root_mean_squared_error: 0.5888
# Epoch 12/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4314 - root_mean_squared_error: 0.6568 - val_loss: 0.3452 - val_root_mean_squared_error: 0.5875
# Epoch 13/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4256 - root_mean_squared_error: 0.6524 - val_loss: 0.3405 - val_root_mean_squared_error: 0.5835
# Epoch 14/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4271 - root_mean_squared_error: 0.6535 - val_loss: 0.3400 - val_root_mean_squared_error: 0.5831
# Epoch 15/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4273 - root_mean_squared_error: 0.6537 - val_loss: 0.3414 - val_root_mean_squared_error: 0.5843
# Epoch 16/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4210 - root_mean_squared_error: 0.6489 - val_loss: 0.3468 - val_root_mean_squared_error: 0.5889
# Epoch 17/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4211 - root_mean_squared_error: 0.6489 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5819
# Epoch 18/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4226 - root_mean_squared_error: 0.6501 - val_loss: 0.3411 - val_root_mean_squared_error: 0.5840
# Epoch 19/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4238 - root_mean_squared_error: 0.6510 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5828
# Epoch 20/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4243 - root_mean_squared_error: 0.6514 - val_loss: 0.3403 - val_root_mean_squared_error: 0.5833
# Epoch 21/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4190 - root_mean_squared_error: 0.6473 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5828
# Epoch 22/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4206 - root_mean_squared_error: 0.6485 - val_loss: 0.3365 - val_root_mean_squared_error: 0.5801
# Epoch 23/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4183 - root_mean_squared_error: 0.6467 - val_loss: 0.3424 - val_root_mean_squared_error: 0.5851
# Epoch 24/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4177 - root_mean_squared_error: 0.6463 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823
# Epoch 25/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4184 - root_mean_squared_error: 0.6468 - val_loss: 0.3402 - val_root_mean_squared_error: 0.5832
# Epoch 26/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4200 - root_mean_squared_error: 0.6481 - val_loss: 0.3356 - val_root_mean_squared_error: 0.5793
# Epoch 27/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4173 - root_mean_squared_error: 0.6460 - val_loss: 0.3381 - val_root_mean_squared_error: 0.5815
# Epoch 28/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4166 - root_mean_squared_error: 0.6455 - val_loss: 0.3426 - val_root_mean_squared_error: 0.5853
# Epoch 29/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4137 - root_mean_squared_error: 0.6432 - val_loss: 0.3413 - val_root_mean_squared_error: 0.5842
# Epoch 30/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4160 - root_mean_squared_error: 0.6450 - val_loss: 0.3374 - val_root_mean_squared_error: 0.5809
# Epoch 31/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4131 - root_mean_squared_error: 0.6427 - val_loss: 0.3355 - val_root_mean_squared_error: 0.5793
# Epoch 32/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4136 - root_mean_squared_error: 0.6432 - val_loss: 0.3377 - val_root_mean_squared_error: 0.5811
# Epoch 33/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4132 - root_mean_squared_error: 0.6428 - val_loss: 0.3370 - val_root_mean_squared_error: 0.5805
# Epoch 34/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4147 - root_mean_squared_error: 0.6440 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5810
# Epoch 35/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4118 - root_mean_squared_error: 0.6418 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5804
# Epoch 36/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4138 - root_mean_squared_error: 0.6432 - val_loss: 0.3352 - val_root_mean_squared_error: 0.5789
# Epoch 37/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4128 - root_mean_squared_error: 0.6425 - val_loss: 0.3415 - val_root_mean_squared_error: 0.5844
# Epoch 38/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4125 - root_mean_squared_error: 0.6423 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5819
# Epoch 39/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4110 - root_mean_squared_error: 0.6411 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5797
# Epoch 40/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4104 - root_mean_squared_error: 0.6406 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5804
# Epoch 41/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4104 - root_mean_squared_error: 0.6406 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5797
# Epoch 42/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4085 - root_mean_squared_error: 0.6392 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5796
# Epoch 43/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4075 - root_mean_squared_error: 0.6384 - val_loss: 0.3356 - val_root_mean_squared_error: 0.5793
# Epoch 44/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4083 - root_mean_squared_error: 0.6390 - val_loss: 0.3374 - val_root_mean_squared_error: 0.5809
# Epoch 45/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4087 - root_mean_squared_error: 0.6393 - val_loss: 0.3363 - val_root_mean_squared_error: 0.5799
# Epoch 46/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4071 - root_mean_squared_error: 0.6381 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 47/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4049 - root_mean_squared_error: 0.6363 - val_loss: 0.3363 - val_root_mean_squared_error: 0.5799
# Epoch 48/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4085 - root_mean_squared_error: 0.6392 - val_loss: 0.3353 - val_root_mean_squared_error: 0.5791
# Epoch 49/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4096 - root_mean_squared_error: 0.6400 - val_loss: 0.3372 - val_root_mean_squared_error: 0.5807
# Epoch 50/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4087 - root_mean_squared_error: 0.6393 - val_loss: 0.3362 - val_root_mean_squared_error: 0.5798
# Epoch 51/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4078 - root_mean_squared_error: 0.6386 - val_loss: 0.3352 - val_root_mean_squared_error: 0.5790
# Epoch 52/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4104 - root_mean_squared_error: 0.6406 - val_loss: 0.3356 - val_root_mean_squared_error: 0.5793
# Epoch 53/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4027 - root_mean_squared_error: 0.6346 - val_loss: 0.3377 - val_root_mean_squared_error: 0.5811
# Epoch 54/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4066 - root_mean_squared_error: 0.6376 - val_loss: 0.3353 - val_root_mean_squared_error: 0.5790
# Epoch 55/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4049 - root_mean_squared_error: 0.6364 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5809
# Epoch 56/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4094 - root_mean_squared_error: 0.6399 - val_loss: 0.3362 - val_root_mean_squared_error: 0.5799
# Epoch 57/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4040 - root_mean_squared_error: 0.6356 - val_loss: 0.3362 - val_root_mean_squared_error: 0.5798
# Epoch 58/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4047 - root_mean_squared_error: 0.6361 - val_loss: 0.3346 - val_root_mean_squared_error: 0.5784
# Epoch 59/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4063 - root_mean_squared_error: 0.6374 - val_loss: 0.3347 - val_root_mean_squared_error: 0.5785
# Epoch 60/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4062 - root_mean_squared_error: 0.6373 - val_loss: 0.3371 - val_root_mean_squared_error: 0.5806
# Epoch 61/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4050 - root_mean_squared_error: 0.6364 - val_loss: 0.3343 - val_root_mean_squared_error: 0.5781
# Epoch 62/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4042 - root_mean_squared_error: 0.6358 - val_loss: 0.3371 - val_root_mean_squared_error: 0.5806
# Epoch 63/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4031 - root_mean_squared_error: 0.6349 - val_loss: 0.3359 - val_root_mean_squared_error: 0.5796
# Epoch 64/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4076 - root_mean_squared_error: 0.6384 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5824
# Epoch 65/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4049 - root_mean_squared_error: 0.6363 - val_loss: 0.3361 - val_root_mean_squared_error: 0.5797
# Epoch 66/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4033 - root_mean_squared_error: 0.6351 - val_loss: 0.3348 - val_root_mean_squared_error: 0.5786
# Epoch 67/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4037 - root_mean_squared_error: 0.6354 - val_loss: 0.3385 - val_root_mean_squared_error: 0.5818
# Epoch 68/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4034 - root_mean_squared_error: 0.6352 - val_loss: 0.3381 - val_root_mean_squared_error: 0.5815
# Epoch 69/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4044 - root_mean_squared_error: 0.6359 - val_loss: 0.3381 - val_root_mean_squared_error: 0.5814
# Epoch 70/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4021 - root_mean_squared_error: 0.6341 - val_loss: 0.3371 - val_root_mean_squared_error: 0.5806
# Epoch 71/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4053 - root_mean_squared_error: 0.6367 - val_loss: 0.3359 - val_root_mean_squared_error: 0.5796
# Epoch 72/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3996 - root_mean_squared_error: 0.6322 - val_loss: 0.3371 - val_root_mean_squared_error: 0.5806
# Epoch 73/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4007 - root_mean_squared_error: 0.6330 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5804
# Epoch 74/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4002 - root_mean_squared_error: 0.6327 - val_loss: 0.3366 - val_root_mean_squared_error: 0.5802
# Epoch 75/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4028 - root_mean_squared_error: 0.6346 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5810
# Epoch 76/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4009 - root_mean_squared_error: 0.6332 - val_loss: 0.3390 - val_root_mean_squared_error: 0.5823
# Epoch 77/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4004 - root_mean_squared_error: 0.6327 - val_loss: 0.3427 - val_root_mean_squared_error: 0.5854
# Epoch 78/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4020 - root_mean_squared_error: 0.6340 - val_loss: 0.3380 - val_root_mean_squared_error: 0.5814
# Epoch 79/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4032 - root_mean_squared_error: 0.6350 - val_loss: 0.3360 - val_root_mean_squared_error: 0.5797
# Epoch 80/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3977 - root_mean_squared_error: 0.6306 - val_loss: 0.3380 - val_root_mean_squared_error: 0.5814
# Epoch 81/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4017 - root_mean_squared_error: 0.6338 - val_loss: 0.3364 - val_root_mean_squared_error: 0.5800
# Epoch 82/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3987 - root_mean_squared_error: 0.6315 - val_loss: 0.3377 - val_root_mean_squared_error: 0.5811
# Epoch 83/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3989 - root_mean_squared_error: 0.6316 - val_loss: 0.3384 - val_root_mean_squared_error: 0.5817
# Epoch 84/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3981 - root_mean_squared_error: 0.6309 - val_loss: 0.3368 - val_root_mean_squared_error: 0.5803
# Epoch 85/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3999 - root_mean_squared_error: 0.6324 - val_loss: 0.3396 - val_root_mean_squared_error: 0.5828
# Epoch 86/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3972 - root_mean_squared_error: 0.6303 - val_loss: 0.3372 - val_root_mean_squared_error: 0.5807
# Epoch 87/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4002 - root_mean_squared_error: 0.6326 - val_loss: 0.3351 - val_root_mean_squared_error: 0.5789
# Epoch 88/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3993 - root_mean_squared_error: 0.6319 - val_loss: 0.3388 - val_root_mean_squared_error: 0.5821
# Epoch 89/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3986 - root_mean_squared_error: 0.6313 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5810
# Epoch 90/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3999 - root_mean_squared_error: 0.6324 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5811
# Epoch 91/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3973 - root_mean_squared_error: 0.6303 - val_loss: 0.3407 - val_root_mean_squared_error: 0.5837
# Epoch 92/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3989 - root_mean_squared_error: 0.6315 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5810
# Epoch 93/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3980 - root_mean_squared_error: 0.6309 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5811
# Epoch 94/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3965 - root_mean_squared_error: 0.6296 - val_loss: 0.3375 - val_root_mean_squared_error: 0.5809
# Epoch 95/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4004 - root_mean_squared_error: 0.6328 - val_loss: 0.3391 - val_root_mean_squared_error: 0.5823
# Epoch 96/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4014 - root_mean_squared_error: 0.6335 - val_loss: 0.3386 - val_root_mean_squared_error: 0.5819
# Epoch 97/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3953 - root_mean_squared_error: 0.6287 - val_loss: 0.3419 - val_root_mean_squared_error: 0.5847
# Epoch 98/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3989 - root_mean_squared_error: 0.6316 - val_loss: 0.3378 - val_root_mean_squared_error: 0.5812
# Epoch 99/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3982 - root_mean_squared_error: 0.6310 - val_loss: 0.3380 - val_root_mean_squared_error: 0.5814
# Epoch 100/100
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3982 - root_mean_squared_error: 0.6310 - val_loss: 0.3376 - val_root_mean_squared_error: 0.5810

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %% [markdown]
# <h1>Prediction</h1>
