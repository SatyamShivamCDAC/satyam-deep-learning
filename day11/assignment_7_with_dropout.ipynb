# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# Names and PRN for all group members:
# - Name: ______________________
# - PRN:  ______________________
# - Date: ______________________

# %% [markdown]
# # Image Processing with Neural Network
# ## A07: Group Assignment
#
#
# ##  Convolutional Neural Network (CNN)
#
# - Flowers Dataset

# %%
###-----------------
### Import Libraries
###-----------------
import os
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.metrics import accuracy_score,classification_report
from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix,fn_plot_label


# %matplotlib inline

# %%
###----------------------
### Some basic parameters
###----------------------

# inpDir = Path('.') # location where input data is stored
# outDir = Path('.') # location to store outputs
subDir = 'flower_photos' # location of the images
modelDir = Path('../models') # location to save model files
valDir = 'valid_flowers' # location related to this dataset
altName = 'base_flowers' # Model file name for this alternative

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE)


EPOCHS = 100   # number of cycles to run
ALPHA = 0.001
BATCH_SIZE = 16
TEST_SIZE = 0.2
IMG_HEIGHT = 190
IMG_WIDTH = 190

# Transformations
# flipping
FLIP_MODE = "horizontal_and_vertical"
# Rotation
ROTATION_FACTOR = (-0.1, 0.1)
# filling mode
FILL_MODE = 'nearest'


## Early Stopping
ES_PATIENCE = 20 # if performance does not improve stop
# Learning rates
LR_PATIENCE = 10 # if performace is not improving reduce alpha
LR_FACTOR = 0.5 # rate of reduction of alpha


# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,8),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Basic Hygiene

# %%
# ###------------------
# ### Memory Management
# ###------------------

# physical_devices = tf.config.list_physical_devices('GPU')

# if len(physical_devices) > 0:
#     tf.config.experimental.set_memory_growth(physical_devices[0], True)
#     print (physical_devices)
# else:
#     print ('Error: No GPU device found')

# %% [markdown]
# ## Helper Functions
# **Note** all helper functions have been moved to util.helper

# %% [markdown]
# ## Load Dataset
#
# Images are under flower_photos
#
#      |- daisy
#      |- dandelion
#      |- roses
#      |- sunflowers
#      |- tulips

# %%
'''
    For reading from web link
'''

# import pathlib
# dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
# data_dir = tf.keras.utils.get_file(origin=dataset_url,
#                                   fname='flower_photos',
#                                   untar=True)
# data_dir = pathlib.Path(data_dir) / 'flower_photos'
# '''
#     For reading from local directory
# '''
data_dir = os.path.join('../datasets/dnn_input/flower_photos/')

# %%
# import tensorflow as tf
# import pathlib
# import os

# # Download and extract dataset
# dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
# data_dir = tf.keras.utils.get_file(
#     fname='flower_photos',
#     origin=dataset_url,
#     untar=True
# )

# # Convert to pathlib Path object for easy path operations
# data_dir = pathlib.Path(data_dir) / 'flower_photos'
# print(f"Dataset downloaded and extracted to: {data_dir}")

# # Example: load dataset using image_dataset_from_directory
# dataset = tf.keras.utils.image_dataset_from_directory(str(data_dir))

# # If you want to access the images later, you can list files like this:
# image_files = list(data_dir.glob('*/*.jpg'))
# print(f"Number of images: {len(image_files)}")

# # If you want to save or reference this directory within Colab session use this path:
# print(f"Local directory path in Colab: {data_dir}")

# %%
data_dir
# Out:
# '../datasets/dnn_input/flower_photos/'

# %%
# list content of data_dir
os.listdir(data_dir)
# Out:
# ['LICENSE.txt', 'daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=TEST_SIZE,
    subset='training',
    seed= RANDOM_STATE,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=TEST_SIZE,
    subset='validation',
    seed= RANDOM_STATE,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %% [markdown]
# ### Is it picking the class names?

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print('total ', num_classes, class_names)
# Out:
# total  5 ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first batch from the training set and display the class name below each image.

# %%
# set figure size
fig = plt.figure()  # figure size in inches with default params

# Adjust the subplot layout parameters.
fig.subplots_adjust(left=0., # as a fraction of the figure width
                    right=1., # use full width, as a fraction of the figure width
                    bottom=0., # as a fraction of the figure height
                    top=1., # as a fraction of the figure height
                    hspace=0.05, # as a fraction of the average Axes height
                    wspace=0.05) # width of the padding between subplots

# take one batch of the dataset
for images, labels in train_ds.take(1):

    # iterate through the batch
    for i in range(BATCH_SIZE):

        # add a subplot
        ax = fig.add_subplot( BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[]) # add a subplot to the figure

        # image_size may have converted these images to float
        ax.imshow(images[i].numpy().astype("uint8"))

        # display class in the title
        ax.set_title(class_names[labels[i]])

# fit the subplot(s) in to the figure area
plt.tight_layout()

# display all open images
plt.show()

# %%
# how many examples in each of the class
fn_plot_label(train_ds, test_ds)

# %%
images[0].shape
# Out:
# TensorShape([190, 190, 3])

# %%
# layer = tf.keras.layers.RandomZoom(height_factor = (-0.2,0.2),
#                              width_factor = (-0.2,0.2))

layer = tf.keras.layers.RandomRotation((-0.5,0.5),fill_mode='nearest')

plt.figure()
img_num = 0
for images,labels in train_ds.take(1):
    out_images = layer(images)
plt.subplot(1,2,1)
plt.title('original')
plt.imshow(images[img_num].numpy().astype('uint16'))

plt.subplot(1,2,2)
plt.title('output')
plt.imshow(out_images[img_num].numpy().astype('uint16'))

# %% [markdown]
# <h1>BUILD MODEL</h1>

# %%
input_shape = [IMG_HEIGHT,IMG_WIDTH,3]

# %%
def build_model(input_shape, num_classes):

    regularizer = tf.keras.regularizers.L2(l2 = 0.001)

    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape = input_shape))
    model.add(tf.keras.layers.Rescaling(1./255))


    #set 1
    model.add(tf.keras.layers.Conv2D(32,(3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #188 x 188 x 32
    model.add(tf.keras.layers.MaxPool2D()) # 94 x 94 x32

    #set 2
    model.add(tf.keras.layers.Conv2D(64, (3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #92 x 92 x 64
    model.add(tf.keras.layers.MaxPool2D()) # 46 x 46 x64


    #set 3
    model.add(tf.keras.layers.Conv2D(128, (3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #44 x 44 x 128
    model.add(tf.keras.layers.MaxPool2D()) # 22 x 22 x128


    #set 4
    model.add(tf.keras.layers.Conv2D(256, (3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #20 x 20 x 256
    model.add(tf.keras.layers.MaxPool2D()) # 10 x 10 x256


    #set 5
    model.add(tf.keras.layers.Conv2D(512, (3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) # 8 x 8 x 512
    model.add(tf.keras.layers.MaxPool2D()) # 4 x 4 x512


    #set 6
    model.add(tf.keras.layers.Conv2D(1024, (3,3),padding='same',
                                 kernel_regularizer=regularizer,
                                 activation='relu')) #2 x 2 x 1024
    model.add(tf.keras.layers.ReLU())
    model.add(tf.keras.layers.Flatten()) # 4096


    # Head
    model.add(tf.keras.layers.Dense(1024,
              kernel_regularizer = regularizer,
              activation='relu')) # 1024

    #Output
    model.add(tf.keras.layers.Dense(num_classes))





    return model
model = build_model(input_shape,num_classes)
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)              │ (None, 190, 190, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 190, 190, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 95, 95, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 95, 95, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 47, 47, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 47, 47, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_17 (MaxPooling2D)      │ (None, 23, 23, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 23, 23, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_18 (MaxPooling2D)      │ (None, 11, 11, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 11, 11, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_19 (MaxPooling2D)      │ (None, 5, 5, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 5, 5, 1024)          │       4,719,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_3 (ReLU)                       │ (None, 5, 5, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 25600)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │      26,215,424 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │           5,125 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,508,741 (124.01 MB)
#  Trainable params: 32,508,741 (124.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#call backs
PATIENCE = 20
LR_FACTOR =0.1
LR_PATIENCE = 5
MIN_LR = 1e-6

es_callback = tf.keras.callbacks.EarlyStopping(monitor= 'val_loss',
                                              patience=PATIENCE,
                                              verbose = 1,
                                              restore_best_weights=True,
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
   monitor='val_loss',
    factor= LR_FACTOR,
    patience = LR_PATIENCE,
    verbose = 1,
    mode = 'auto',
    min_lr=MIN_LR
)

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate = ALPHA)
model.compile(optimizer = optimizer,
             loss = loss_fn,

             metrics = ['accuracy'])

# %%
history = model.fit(train_ds,
         validation_data=test_ds,
         epochs= EPOCHS,
         callbacks=[es_callback,lr_callback])
# Out:
# Epoch 1/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 562ms/step - accuracy: 0.2432 - loss: 2.1984 - val_accuracy: 0.2384 - val_loss: 1.7927 - learning_rate: 0.0010
# Epoch 2/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 543ms/step - accuracy: 0.2463 - loss: 1.7216 - val_accuracy: 0.2384 - val_loss: 1.6779 - learning_rate: 0.0010
# Epoch 3/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 546ms/step - accuracy: 0.2463 - loss: 1.6569 - val_accuracy: 0.2384 - val_loss: 1.6436 - learning_rate: 0.0010
# Epoch 4/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 541ms/step - accuracy: 0.2463 - loss: 1.6338 - val_accuracy: 0.2384 - val_loss: 1.6286 - learning_rate: 0.0010
# Epoch 5/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 544ms/step - accuracy: 0.2463 - loss: 1.6226 - val_accuracy: 0.2384 - val_loss: 1.6206 - learning_rate: 0.0010
# Epoch 6/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 104s 566ms/step - accuracy: 0.2463 - loss: 1.6164 - val_accuracy: 0.2384 - val_loss: 1.6156 - learning_rate: 0.0010
# Epoch 7/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 99s 539ms/step - accuracy: 0.2463 - loss: 1.6121 - val_accuracy: 0.2384 - val_loss: 1.6120 - learning_rate: 0.0010
# Epoch 8/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 102s 552ms/step - accuracy: 0.2463 - loss: 1.6095 - val_accuracy: 0.2384 - val_loss: 1.6099 - learning_rate: 0.0010
# Epoch 9/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 103s 561ms/step - accuracy: 0.2463 - loss: 1.6077 - val_accuracy: 0.2384 - val_loss: 1.6083 - learning_rate: 0.0010
# Epoch 10/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 576ms/step - accuracy: 0.2463 - loss: 1.6063 - val_accuracy: 0.2384 - val_loss: 1.6071 - learning_rate: 0.0010
# Epoch 11/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 105s 571ms/step - accuracy: 0.2463 - loss: 1.6050 - val_accuracy: 0.2384 - val_loss: 1.6061 - learning_rate: 0.0010
# Epoch 12/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 105s 573ms/step - accuracy: 0.2463 - loss: 1.6041 - val_accuracy: 0.2384 - val_loss: 1.6052 - learning_rate: 0.0010
# Epoch 13/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 102s 554ms/step - accuracy: 0.2463 - loss: 1.6033 - val_accuracy: 0.2384 - val_loss: 1.6047 - learning_rate: 0.0010
# Epoch 14/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 99s 537ms/step - accuracy: 0.2463 - loss: 1.6030 - val_accuracy: 0.2384 - val_loss: 1.6041 - learning_rate: 0.0010
# Epoch 15/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 101s 549ms/step - accuracy: 0.2463 - loss: 1.6023 - val_accuracy: 0.2384 - val_loss: 1.6039 - learning_rate: 0.0010
# Epoch 16/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 101s 549ms/step - accuracy: 0.2463 - loss: 1.6020 - val_accuracy: 0.2384 - val_loss: 1.6037 - learning_rate: 0.0010
# Epoch 17/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 544ms/step - accuracy: 0.2463 - loss: 1.6015 - val_accuracy: 0.2384 - val_loss: 1.6035 - learning_rate: 0.0010
# Epoch 18/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 545ms/step - accuracy: 0.2463 - loss: 1.6014 - val_accuracy: 0.2384 - val_loss: 1.6030 - learning_rate: 0.0010
# Epoch 19/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 103s 558ms/step - accuracy: 0.2463 - loss: 1.6011 - val_accuracy: 0.2384 - val_loss: 1.6031 - learning_rate: 0.0010
# Epoch 20/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 105s 569ms/step - accuracy: 0.2463 - loss: 1.6008 - val_accuracy: 0.2384 - val_loss: 1.6027 - learning_rate: 0.0010
# Epoch 21/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 574ms/step - accuracy: 0.2463 - loss: 1.6009 - val_accuracy: 0.2384 - val_loss: 1.6026 - learning_rate: 0.0010
# Epoch 22/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 575ms/step - accuracy: 0.2463 - loss: 1.6007 - val_accuracy: 0.2384 - val_loss: 1.6024 - learning_rate: 0.0010
# Epoch 23/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 575ms/step - accuracy: 0.2463 - loss: 1.6009 - val_accuracy: 0.2384 - val_loss: 1.6027 - learning_rate: 0.0010
# Epoch 24/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 107s 580ms/step - accuracy: 0.2463 - loss: 1.6006 - val_accuracy: 0.2384 - val_loss: 1.6024 - learning_rate: 0.0010
# Epoch 25/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 105s 570ms/step - accuracy: 0.2463 - loss: 1.6005 - val_accuracy: 0.2384 - val_loss: 1.6024 - learning_rate: 0.0010
# Epoch 26/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 105s 568ms/step - accuracy: 0.2463 - loss: 1.6005 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 0.0010
# Epoch 27/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 106s 573ms/step - accuracy: 0.2463 - loss: 1.6006 - val_accuracy: 0.2384 - val_loss: 1.6024 - learning_rate: 0.0010
# Epoch 28/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 102s 551ms/step - accuracy: 0.2463 - loss: 1.6005 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 0.0010
# Epoch 29/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 102s 552ms/step - accuracy: 0.2463 - loss: 1.6005 - val_accuracy: 0.2384 - val_loss: 1.6022 - learning_rate: 0.0010
# Epoch 30/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 104s 566ms/step - accuracy: 0.2463 - loss: 1.6004 - val_accuracy: 0.2384 - val_loss: 1.6021 - learning_rate: 0.0010
# Epoch 31/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 102s 557ms/step - accuracy: 0.2463 - loss: 1.6003 - val_accuracy: 0.2384 - val_loss: 1.6022 - learning_rate: 0.0010
# Epoch 32/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 103s 559ms/step - accuracy: 0.2463 - loss: 1.6004 - val_accuracy: 0.2384 - val_loss: 1.6021 - learning_rate: 0.0010
# Epoch 33/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 103s 558ms/step - accuracy: 0.2463 - loss: 1.6006 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 0.0010
# Epoch 34/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.2438 - loss: 1.6018
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 534ms/step - accuracy: 0.2463 - loss: 1.6003 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 0.0010
# Epoch 35/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 100s 544ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-04
# Epoch 36/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 534ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-04
# Epoch 37/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 532ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-04
# Epoch 38/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 99s 535ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-04
# Epoch 39/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.2406 - loss: 1.6024
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 533ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-04
# Epoch 40/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 531ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-05
# Epoch 41/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 535ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-05
# Epoch 42/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 533ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-05
# Epoch 43/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 97s 528ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-05
# Epoch 44/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.2418 - loss: 1.6017
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 97s 528ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-05
# Epoch 45/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 97s 528ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 46/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 97s 530ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 47/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 533ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 48/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 532ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 49/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.2428 - loss: 1.6021
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1e-06.
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 532ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 50/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 99s 535ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 51/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 98s 533ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 52/100
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 97s 529ms/step - accuracy: 0.2463 - loss: 1.5998 - val_accuracy: 0.2384 - val_loss: 1.6023 - learning_rate: 1.0000e-06
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %% [markdown]
# ### Reload best Weights for evaluation

# %% [markdown]
# ### Evaluate the model

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
y_train = tf.concat([y for x, y in train_ds], axis=0).numpy()
print(y_train.shape)
# Out:
# (2936,)

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_train, y_pred):.5f}')
print(classification_report(y_train, y_pred))
# Out:
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step
# Accuracy: 0.22037
#               precision    recall  f1-score   support
#
#            0       0.18      0.17      0.18       493
#            1       0.25      0.32      0.28       723
#            2       0.22      0.22      0.22       525
#            3       0.21      0.21      0.21       561
#            4       0.22      0.16      0.18       634
#
#     accuracy                           0.22      2936
#    macro avg       0.22      0.22      0.21      2936
# weighted avg       0.22      0.22      0.22      2936

# %%
y_train = tf.concat([y for x, y in train_ds], axis=0).numpy()
print(y_train.shape)
# Out:
# (2936,)

# %%
yhat = model.predict(train_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_train, y_pred):.5f}')
print(classification_report(y_train, y_pred))
# Out:
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step
# Accuracy: 0.20232
#               precision    recall  f1-score   support
#
#            0       0.19      0.17      0.18       493
#            1       0.23      0.29      0.26       723
#            2       0.16      0.16      0.16       525
#            3       0.18      0.18      0.18       561
#            4       0.23      0.17      0.20       634
#
#     accuracy                           0.20      2936
#    macro avg       0.20      0.20      0.20      2936
# weighted avg       0.20      0.20      0.20      2936

# %%
fn_plot_confusion_matrix(y_train, y_pred, class_names)

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in train_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Validate on the validation set

# %%
# loss, acc = model.evaluate(valid_ds)

# print('Accuracy score on Validation Data : {:.3f}%'.format( acc*100))
# Out:
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.1582 - loss: 3.1945
# Accuracy score on Validation Data : 16.185%

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0).numpy()
print(y_test.shape)
# Out:
# (734,)

# %%
yhat = model.predict(test_ds)
y_pred = yhat.argmax(axis=1)
print(f'Accuracy: {accuracy_score(y_test, y_pred):.5f}')
print(classification_report(y_test, y_pred))
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Accuracy: 0.21117
#               precision    recall  f1-score   support
#
#            0       0.22      0.21      0.21       140
#            1       0.26      0.31      0.28       175
#            2       0.17      0.20      0.18       116
#            3       0.17      0.19      0.18       138
#            4       0.21      0.14      0.17       165
#
#     accuracy                           0.21       734
#    macro avg       0.21      0.21      0.21       734
# weighted avg       0.21      0.21      0.21       734

# %%
fig = plt.figure()
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

i=0
for images, labels in test_ds.take(1):
    yhat = model(images).numpy()
    y_pred = yhat.argmax(axis=1)
    for i in range(BATCH_SIZE):
        ax = fig.add_subplot(BATCH_SIZE//8, 8, (i+1), xticks=[], yticks=[])
        ax.grid(False)
        color = 'cyan'
        if y_pred[i] != labels[i]:
            color = 'red'
        props = dict(boxstyle = 'round',facecolor = color,alpha = 0.5)
        ax.imshow(images[i].numpy().astype('uint8'), cmap=plt.cm.binary, interpolation='nearest')
        # ax.text(2,4, str(labels[i].numpy()), color='b', fontsize=14)
        # ax.text(10,25, class_names[labels[i].numpy()], color='r', fontsize=10)
        ax.text(0.1,0.90,class_names[y_pred[i]],bbox = props,
               verticalalignment = 'top',
               transform = ax.transAxes,fontsize = 14)
        ax.set_title(class_names[labels[i].numpy()],fontsize = 14)
plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1737978280.py in <cell line: 0>()
# ----> 1 fn_plot_confusion_matrix(y_test, y_pred, class_names)
#
# /content/utils/helper.py in fn_plot_confusion_matrix(y_true, y_pred, labels)
#     404     '''
#     405
# --> 406     cm  = confusion_matrix(y_true, y_pred)
#     407
#     408     if isinstance(labels, dict):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     338     """
#     339     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 340     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     341     if y_type not in ("binary", "multiclass"):
#     342         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      96     """
#      97     xp, _ = get_namespace(y_true, y_pred)
# ---> 98     check_consistent_length(y_true, y_pred)
#      99     type_true = type_of_target(y_true, input_name="y_true")
#     100     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [734, 16]
